# %% [markdown]
# # Testing BatchNorm in Pytorch

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
from baseSetterHelper import setAllSeeds, setDeterministic, computeAccu
from trainerHelper import modelTrainer
from plottingHelper import plotTrainingLoss, plotAccuracy, show_examples
from dataLoaderHelper import getDataLoadersMNIST

# %% [markdown]
# ## Setting Parameters

# %%
RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
setAllSeeds(RANDOM_SEED)
setDeterministic()

# %% [markdown]
# ## Data Imports

# %%
trainLoader, validLoader, testLoader = getDataLoadersMNIST(
    batchSize=BATCH_SIZE,
    validFraction=0.1)

# Checking the dataset
for images, labels in trainLoader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 113975692.67it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 57931943.48it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 33526067.93it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4035274.05it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Image batch dimensions: torch.Size([256, 1, 28, 28])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 5, 8, 9, 9, 4, 9, 9, 3, 9])

# %% [markdown]
# ## Class Structure

# %%
class MultilayerPerceptron(torch.nn.Module):

    def __init__(self, numFeatures, numClasses, dropProba, numHidden1, numHidden2):
        super().__init__()

        self.my_network = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Flatten(),
            torch.nn.Linear(numFeatures, numHidden1, bias=False),
            torch.nn.BatchNorm1d(numHidden1),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropProba),
            # 2nd hidden layer
            torch.nn.Linear(numHidden1, numHidden2, bias=False),
            torch.nn.BatchNorm1d(numHidden2),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropProba),
            # output layer
            torch.nn.Linear(numHidden2, numClasses)
        )

    def forward(self, x):
        logits = self.my_network(x)
        return logits

# %% [markdown]
# ## Drop Out with Probability 0

# %%
torch.manual_seed(RANDOM_SEED)
model = MultilayerPerceptron(numFeatures=28*28,
                             numHidden1=NUM_HIDDEN_1,
                             numHidden2=NUM_HIDDEN_2,
                             dropProba=0.0,
                             numClasses=10)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
miniBatchLossList, trainAccList, validAccList = modelTrainer(
    model1=model,
    numEpochs=NUM_EPOCHS,
    trainLoader=trainLoader,
    valLoader=validLoader,
    testLoader=testLoader,
    opt=optimizer,
    device=DEVICE)
# Out:
# Epoch:001/050 | Batch:000/210 |  Cost:2.3559
# Epoch:001/050 | Batch:050/210 |  Cost:0.4216
# Epoch:001/050 | Batch:100/210 |  Cost:0.3420
# Epoch:001/050 | Batch:150/210 |  Cost:0.2311
# Epoch:001/050 | Batch:200/210 |  Cost:0.2121
# Epoch:001/050 |
# Train Acc 95.7143%
# Val Acc   96.5500%
# Time Taken: 0.30 min
# Epoch:002/050 | Batch:000/210 |  Cost:0.1470
# Epoch:002/050 | Batch:050/210 |  Cost:0.2062
# Epoch:002/050 | Batch:100/210 |  Cost:0.1260
# Epoch:002/050 | Batch:150/210 |  Cost:0.1255
# Epoch:002/050 | Batch:200/210 |  Cost:0.1484
# Epoch:002/050 |
# Train Acc 97.4182%
# Val Acc   97.3167%
# Time Taken: 0.59 min
# Epoch:003/050 | Batch:000/210 |  Cost:0.1065
# Epoch:003/050 | Batch:050/210 |  Cost:0.0846
# Epoch:003/050 | Batch:100/210 |  Cost:0.0887
# Epoch:003/050 | Batch:150/210 |  Cost:0.0743
# Epoch:003/050 | Batch:200/210 |  Cost:0.1047
# Epoch:003/050 |
# Train Acc 97.9594%
# Val Acc   97.5167%
# Time Taken: 0.91 min
# Epoch:004/050 | Batch:000/210 |  Cost:0.0679
# Epoch:004/050 | Batch:050/210 |  Cost:0.0439
# Epoch:004/050 | Batch:100/210 |  Cost:0.0646
# Epoch:004/050 | Batch:150/210 |  Cost:0.0809
# Epoch:004/050 | Batch:200/210 |  Cost:0.0887
# Epoch:004/050 |
# Train Acc 98.3798%
# Val Acc   97.4167%
# Time Taken: 1.24 min
# Epoch:005/050 | Batch:000/210 |  Cost:0.0490
# Epoch:005/050 | Batch:050/210 |  Cost:0.0887
# Epoch:005/050 | Batch:100/210 |  Cost:0.0380
# Epoch:005/050 | Batch:150/210 |  Cost:0.0765
# Epoch:005/050 | Batch:200/210 |  Cost:0.0442
# Epoch:005/050 |
# Train Acc 98.5603%
# Val Acc   97.6167%
# Time Taken: 1.52 min
# Epoch:006/050 | Batch:000/210 |  Cost:0.0397
# Epoch:006/050 | Batch:050/210 |  Cost:0.0413
# Epoch:006/050 | Batch:100/210 |  Cost:0.0497
# Epoch:006/050 | Batch:150/210 |  Cost:0.0485
# Epoch:006/050 | Batch:200/210 |  Cost:0.0520
# Epoch:006/050 |
# Train Acc 99.0234%
# Val Acc   97.7333%
# Time Taken: 1.82 min
# Epoch:007/050 | Batch:000/210 |  Cost:0.0429
# Epoch:007/050 | Batch:050/210 |  Cost:0.0193
# Epoch:007/050 | Batch:100/210 |  Cost:0.0622
# Epoch:007/050 | Batch:150/210 |  Cost:0.0464
# Epoch:007/050 | Batch:200/210 |  Cost:0.0463
# Epoch:007/050 |
# Train Acc 99.3155%
# Val Acc   97.9333%
# Time Taken: 2.10 min
# Epoch:008/050 | Batch:000/210 |  Cost:0.0168
# Epoch:008/050 | Batch:050/210 |  Cost:0.0180
# Epoch:008/050 | Batch:100/210 |  Cost:0.0597
# Epoch:008/050 | Batch:150/210 |  Cost:0.0422
# Epoch:008/050 | Batch:200/210 |  Cost:0.0372
# Epoch:008/050 |
# Train Acc 99.4327%
# Val Acc   97.8500%
# Time Taken: 2.39 min
# Epoch:009/050 | Batch:000/210 |  Cost:0.0252
# Epoch:009/050 | Batch:050/210 |  Cost:0.0284
# Epoch:009/050 | Batch:100/210 |  Cost:0.0141
# Epoch:009/050 | Batch:150/210 |  Cost:0.0377
# Epoch:009/050 | Batch:200/210 |  Cost:0.0219
# Epoch:009/050 |
# Train Acc 99.4345%
# Val Acc   97.8333%
# Time Taken: 2.68 min
# Epoch:010/050 | Batch:000/210 |  Cost:0.0362
# Epoch:010/050 | Batch:050/210 |  Cost:0.0251
# Epoch:010/050 | Batch:100/210 |  Cost:0.0308
# Epoch:010/050 | Batch:150/210 |  Cost:0.0283
# Epoch:010/050 | Batch:200/210 |  Cost:0.0270
# Epoch:010/050 |
# Train Acc 99.5592%
# Val Acc   97.7500%
# Time Taken: 2.96 min
# Epoch:011/050 | Batch:000/210 |  Cost:0.0242
# Epoch:011/050 | Batch:050/210 |  Cost:0.0145
# Epoch:011/050 | Batch:100/210 |  Cost:0.0189
# Epoch:011/050 | Batch:150/210 |  Cost:0.0213
# Epoch:011/050 | Batch:200/210 |  Cost:0.0298
# Epoch:011/050 |
# Train Acc 99.6726%
# Val Acc   97.5667%
# Time Taken: 3.26 min
# Epoch:012/050 | Batch:000/210 |  Cost:0.0396
# Epoch:012/050 | Batch:050/210 |  Cost:0.0160
# Epoch:012/050 | Batch:100/210 |  Cost:0.0125
# Epoch:012/050 | Batch:150/210 |  Cost:0.0141
# Epoch:012/050 | Batch:200/210 |  Cost:0.0181
# Epoch:012/050 |
# Train Acc 99.6894%
# Val Acc   97.7000%
# Time Taken: 3.55 min
# Epoch:013/050 | Batch:000/210 |  Cost:0.0089
# Epoch:013/050 | Batch:050/210 |  Cost:0.0190
# Epoch:013/050 | Batch:100/210 |  Cost:0.0208
# Epoch:013/050 | Batch:150/210 |  Cost:0.0271
# Epoch:013/050 | Batch:200/210 |  Cost:0.0104
# Epoch:013/050 |
# Train Acc 99.8438%
# Val Acc   97.8833%
# Time Taken: 3.83 min
# Epoch:014/050 | Batch:000/210 |  Cost:0.0071
# Epoch:014/050 | Batch:050/210 |  Cost:0.0146
# Epoch:014/050 | Batch:100/210 |  Cost:0.0252
# Epoch:014/050 | Batch:150/210 |  Cost:0.0164
# Epoch:014/050 | Batch:200/210 |  Cost:0.0254
# Epoch:014/050 |
# Train Acc 99.7805%
# Val Acc   97.7333%
# Time Taken: 4.12 min
# Epoch:015/050 | Batch:000/210 |  Cost:0.0103
# Epoch:015/050 | Batch:050/210 |  Cost:0.0110
# Epoch:015/050 | Batch:100/210 |  Cost:0.0195
# Epoch:015/050 | Batch:150/210 |  Cost:0.0274
# Epoch:015/050 | Batch:200/210 |  Cost:0.0153
# Epoch:015/050 |
# Train Acc 99.7991%
# Val Acc   97.8000%
# Time Taken: 4.41 min
# Epoch:016/050 | Batch:000/210 |  Cost:0.0144
# Epoch:016/050 | Batch:050/210 |  Cost:0.0172
# Epoch:016/050 | Batch:100/210 |  Cost:0.0110
# Epoch:016/050 | Batch:150/210 |  Cost:0.0149
# Epoch:016/050 | Batch:200/210 |  Cost:0.0136
# Epoch:016/050 |
# Train Acc 99.8828%
# Val Acc   97.9000%
# Time Taken: 4.70 min
# Epoch:017/050 | Batch:000/210 |  Cost:0.0028
# Epoch:017/050 | Batch:050/210 |  Cost:0.0070
# Epoch:017/050 | Batch:100/210 |  Cost:0.0074
# Epoch:017/050 | Batch:150/210 |  Cost:0.0115
# Epoch:017/050 | Batch:200/210 |  Cost:0.0131
# Epoch:017/050 |
# Train Acc 99.9535%
# Val Acc   98.1000%
# Time Taken: 4.98 min
# Epoch:018/050 | Batch:000/210 |  Cost:0.0063
# Epoch:018/050 | Batch:050/210 |  Cost:0.0157
# Epoch:018/050 | Batch:100/210 |  Cost:0.0193
# Epoch:018/050 | Batch:150/210 |  Cost:0.0102
# Epoch:018/050 | Batch:200/210 |  Cost:0.0307
# Epoch:018/050 |
# Train Acc 99.9386%
# Val Acc   97.8667%
# Time Taken: 5.27 min
# Epoch:019/050 | Batch:000/210 |  Cost:0.0097
# Epoch:019/050 | Batch:050/210 |  Cost:0.0072
# Epoch:019/050 | Batch:100/210 |  Cost:0.0122
# Epoch:019/050 | Batch:150/210 |  Cost:0.0103
# Epoch:019/050 | Batch:200/210 |  Cost:0.0087
# Epoch:019/050 |
# Train Acc 99.9237%
# Val Acc   97.9167%
# Time Taken: 5.56 min
# Epoch:020/050 | Batch:000/210 |  Cost:0.0049
# Epoch:020/050 | Batch:050/210 |  Cost:0.0074
# Epoch:020/050 | Batch:100/210 |  Cost:0.0048
# Epoch:020/050 | Batch:150/210 |  Cost:0.0092
# Epoch:020/050 | Batch:200/210 |  Cost:0.0091
# Epoch:020/050 |
# Train Acc 99.9461%
# Val Acc   97.9500%
# Time Taken: 5.84 min
# Epoch:021/050 | Batch:000/210 |  Cost:0.0123
# Epoch:021/050 | Batch:050/210 |  Cost:0.0062
# Epoch:021/050 | Batch:100/210 |  Cost:0.0085
# Epoch:021/050 | Batch:150/210 |  Cost:0.0055
# Epoch:021/050 | Batch:200/210 |  Cost:0.0092
# Epoch:021/050 |
# Train Acc 99.9702%
# Val Acc   97.8167%
# Time Taken: 6.12 min
# Epoch:022/050 | Batch:000/210 |  Cost:0.0057
# Epoch:022/050 | Batch:050/210 |  Cost:0.0041
# Epoch:022/050 | Batch:100/210 |  Cost:0.0076
# Epoch:022/050 | Batch:150/210 |  Cost:0.0060
# Epoch:022/050 | Batch:200/210 |  Cost:0.0068
# Epoch:022/050 |
# Train Acc 99.9684%
# Val Acc   98.0000%
# Time Taken: 6.41 min
# Epoch:023/050 | Batch:000/210 |  Cost:0.0079
# Epoch:023/050 | Batch:050/210 |  Cost:0.0066
# Epoch:023/050 | Batch:100/210 |  Cost:0.0043
# Epoch:023/050 | Batch:150/210 |  Cost:0.0056
# Epoch:023/050 | Batch:200/210 |  Cost:0.0077
# Epoch:023/050 |
# Train Acc 99.9907%
# Val Acc   98.0667%
# Time Taken: 6.70 min
# Epoch:024/050 | Batch:000/210 |  Cost:0.0055
# Epoch:024/050 | Batch:050/210 |  Cost:0.0029
# Epoch:024/050 | Batch:100/210 |  Cost:0.0042
# Epoch:024/050 | Batch:150/210 |  Cost:0.0067
# Epoch:024/050 | Batch:200/210 |  Cost:0.0063
# Epoch:024/050 |
# Train Acc 99.9833%
# Val Acc   97.9167%
# Time Taken: 6.98 min
# Epoch:025/050 | Batch:000/210 |  Cost:0.0034
# Epoch:025/050 | Batch:050/210 |  Cost:0.0034
# Epoch:025/050 | Batch:100/210 |  Cost:0.0098
# Epoch:025/050 | Batch:150/210 |  Cost:0.0048
# Epoch:025/050 | Batch:200/210 |  Cost:0.0049
# Epoch:025/050 |
# Train Acc 99.9665%
# Val Acc   97.9667%
# Time Taken: 7.27 min
# Epoch:026/050 | Batch:000/210 |  Cost:0.0035
# Epoch:026/050 | Batch:050/210 |  Cost:0.0062
# Epoch:026/050 | Batch:100/210 |  Cost:0.0042
# Epoch:026/050 | Batch:150/210 |  Cost:0.0200
# Epoch:026/050 | Batch:200/210 |  Cost:0.0058
# Epoch:026/050 |
# Train Acc 99.9944%
# Val Acc   97.9833%
# Time Taken: 7.55 min
# Epoch:027/050 | Batch:000/210 |  Cost:0.0051
# Epoch:027/050 | Batch:050/210 |  Cost:0.0036
# Epoch:027/050 | Batch:100/210 |  Cost:0.0029
# Epoch:027/050 | Batch:150/210 |  Cost:0.0066
# Epoch:027/050 | Batch:200/210 |  Cost:0.0143
# Epoch:027/050 |
# Train Acc 99.9944%
# Val Acc   97.8500%
# Time Taken: 7.85 min
# Epoch:028/050 | Batch:000/210 |  Cost:0.0056
# Epoch:028/050 | Batch:050/210 |  Cost:0.0060
# Epoch:028/050 | Batch:100/210 |  Cost:0.0047
# Epoch:028/050 | Batch:150/210 |  Cost:0.0128
# Epoch:028/050 | Batch:200/210 |  Cost:0.0061
# Epoch:028/050 |
# Train Acc 99.9963%
# Val Acc   97.9167%
# Time Taken: 8.13 min
# Epoch:029/050 | Batch:000/210 |  Cost:0.0039
# Epoch:029/050 | Batch:050/210 |  Cost:0.0029
# Epoch:029/050 | Batch:100/210 |  Cost:0.0144
# Epoch:029/050 | Batch:150/210 |  Cost:0.0083
# Epoch:029/050 | Batch:200/210 |  Cost:0.0017
# Epoch:029/050 |
# Train Acc 99.9963%
# Val Acc   98.0500%
# Time Taken: 8.41 min
# Epoch:030/050 | Batch:000/210 |  Cost:0.0020
# Epoch:030/050 | Batch:050/210 |  Cost:0.0045
# Epoch:030/050 | Batch:100/210 |  Cost:0.0045
# Epoch:030/050 | Batch:150/210 |  Cost:0.0030
# Epoch:030/050 | Batch:200/210 |  Cost:0.0057
# Epoch:030/050 |
# Train Acc 99.9926%
# Val Acc   98.0667%
# Time Taken: 8.71 min
# Epoch:031/050 | Batch:000/210 |  Cost:0.0017
# Epoch:031/050 | Batch:050/210 |  Cost:0.0012
# Epoch:031/050 | Batch:100/210 |  Cost:0.0033
# Epoch:031/050 | Batch:150/210 |  Cost:0.0043
# Epoch:031/050 | Batch:200/210 |  Cost:0.0020
# Epoch:031/050 |
# Train Acc 100.0000%
# Val Acc   98.1000%
# Time Taken: 9.00 min
# Epoch:032/050 | Batch:000/210 |  Cost:0.0025
# Epoch:032/050 | Batch:050/210 |  Cost:0.0023
# Epoch:032/050 | Batch:100/210 |  Cost:0.0020
# Epoch:032/050 | Batch:150/210 |  Cost:0.0038
# Epoch:032/050 | Batch:200/210 |  Cost:0.0016
# Epoch:032/050 |
# Train Acc 100.0000%
# Val Acc   98.0167%
# Time Taken: 9.29 min
# Epoch:033/050 | Batch:000/210 |  Cost:0.0054
# Epoch:033/050 | Batch:050/210 |  Cost:0.0021
# Epoch:033/050 | Batch:100/210 |  Cost:0.0014
# Epoch:033/050 | Batch:150/210 |  Cost:0.0025
# Epoch:033/050 | Batch:200/210 |  Cost:0.0025
# Epoch:033/050 |
# Train Acc 99.9926%
# Val Acc   97.8833%
# Time Taken: 9.57 min
# Epoch:034/050 | Batch:000/210 |  Cost:0.0034
# Epoch:034/050 | Batch:050/210 |  Cost:0.0043
# Epoch:034/050 | Batch:100/210 |  Cost:0.0240
# Epoch:034/050 | Batch:150/210 |  Cost:0.0018
# Epoch:034/050 | Batch:200/210 |  Cost:0.0029
# Epoch:034/050 |
# Train Acc 99.9944%
# Val Acc   97.9667%
# Time Taken: 9.86 min
# Epoch:035/050 | Batch:000/210 |  Cost:0.0026
# Epoch:035/050 | Batch:050/210 |  Cost:0.0046
# Epoch:035/050 | Batch:100/210 |  Cost:0.0047
# Epoch:035/050 | Batch:150/210 |  Cost:0.0024
# Epoch:035/050 | Batch:200/210 |  Cost:0.0038
# Epoch:035/050 |
# Train Acc 100.0000%
# Val Acc   97.9667%
# Time Taken: 10.16 min
# Epoch:036/050 | Batch:000/210 |  Cost:0.0013
# Epoch:036/050 | Batch:050/210 |  Cost:0.0030
# Epoch:036/050 | Batch:100/210 |  Cost:0.0023
# Epoch:036/050 | Batch:150/210 |  Cost:0.0014
# Epoch:036/050 | Batch:200/210 |  Cost:0.0020
# Epoch:036/050 |
# Train Acc 99.9981%
# Val Acc   98.0167%
# Time Taken: 10.44 min
# Epoch:037/050 | Batch:000/210 |  Cost:0.0013
# Epoch:037/050 | Batch:050/210 |  Cost:0.0053
# Epoch:037/050 | Batch:100/210 |  Cost:0.0040
# Epoch:037/050 | Batch:150/210 |  Cost:0.0027
# Epoch:037/050 | Batch:200/210 |  Cost:0.0017
# Epoch:037/050 |
# Train Acc 100.0000%
# Val Acc   98.0167%
# Time Taken: 10.72 min
# Epoch:038/050 | Batch:000/210 |  Cost:0.0025
# Epoch:038/050 | Batch:050/210 |  Cost:0.0028
# Epoch:038/050 | Batch:100/210 |  Cost:0.0050
# Epoch:038/050 | Batch:150/210 |  Cost:0.0016
# Epoch:038/050 | Batch:200/210 |  Cost:0.0013
# Epoch:038/050 |
# Train Acc 100.0000%
# Val Acc   97.9667%
# Time Taken: 11.02 min
# Epoch:039/050 | Batch:000/210 |  Cost:0.0049
# Epoch:039/050 | Batch:050/210 |  Cost:0.0013
# Epoch:039/050 | Batch:100/210 |  Cost:0.0047
# Epoch:039/050 | Batch:150/210 |  Cost:0.0013
# Epoch:039/050 | Batch:200/210 |  Cost:0.0044
# Epoch:039/050 |
# Train Acc 99.5554%
# Val Acc   97.1000%
# Time Taken: 11.30 min
# Epoch:040/050 | Batch:000/210 |  Cost:0.0151
# Epoch:040/050 | Batch:050/210 |  Cost:0.0027
# Epoch:040/050 | Batch:100/210 |  Cost:0.0010
# Epoch:040/050 | Batch:150/210 |  Cost:0.0106
# Epoch:040/050 | Batch:200/210 |  Cost:0.0016
# Epoch:040/050 |
# Train Acc 100.0000%
# Val Acc   97.9667%
# Time Taken: 11.59 min
# Epoch:041/050 | Batch:000/210 |  Cost:0.0020
# Epoch:041/050 | Batch:050/210 |  Cost:0.0067
# Epoch:041/050 | Batch:100/210 |  Cost:0.0028
# Epoch:041/050 | Batch:150/210 |  Cost:0.0024
# Epoch:041/050 | Batch:200/210 |  Cost:0.0012
# Epoch:041/050 |
# Train Acc 100.0000%
# Val Acc   98.0000%
# Time Taken: 11.88 min
# Epoch:042/050 | Batch:000/210 |  Cost:0.0024
# Epoch:042/050 | Batch:050/210 |  Cost:0.0023
# Epoch:042/050 | Batch:100/210 |  Cost:0.0009
# Epoch:042/050 | Batch:150/210 |  Cost:0.0004
# Epoch:042/050 | Batch:200/210 |  Cost:0.0019
# Epoch:042/050 |
# Train Acc 100.0000%
# Val Acc   97.9667%
# Time Taken: 12.16 min
# Epoch:043/050 | Batch:000/210 |  Cost:0.0024
# Epoch:043/050 | Batch:050/210 |  Cost:0.0011
# Epoch:043/050 | Batch:100/210 |  Cost:0.0030
# Epoch:043/050 | Batch:150/210 |  Cost:0.0025
# Epoch:043/050 | Batch:200/210 |  Cost:0.0022
# Epoch:043/050 |
# Train Acc 99.9981%
# Val Acc   98.1000%
# Time Taken: 12.45 min
# Epoch:044/050 | Batch:000/210 |  Cost:0.0025
# Epoch:044/050 | Batch:050/210 |  Cost:0.0054
# Epoch:044/050 | Batch:100/210 |  Cost:0.0014
# Epoch:044/050 | Batch:150/210 |  Cost:0.0011
# Epoch:044/050 | Batch:200/210 |  Cost:0.0018
# Epoch:044/050 |
# Train Acc 100.0000%
# Val Acc   98.0667%
# Time Taken: 12.73 min
# Epoch:045/050 | Batch:000/210 |  Cost:0.0014
# Epoch:045/050 | Batch:050/210 |  Cost:0.0050
# Epoch:045/050 | Batch:100/210 |  Cost:0.0010
# Epoch:045/050 | Batch:150/210 |  Cost:0.0012
# Epoch:045/050 | Batch:200/210 |  Cost:0.0017
# Epoch:045/050 |
# Train Acc 100.0000%
# Val Acc   98.1167%
# Time Taken: 13.02 min
# Epoch:046/050 | Batch:000/210 |  Cost:0.0022
# Epoch:046/050 | Batch:050/210 |  Cost:0.0010
# Epoch:046/050 | Batch:100/210 |  Cost:0.0037
# Epoch:046/050 | Batch:150/210 |  Cost:0.0015
# Epoch:046/050 | Batch:200/210 |  Cost:0.0013
# Epoch:046/050 |
# Train Acc 100.0000%
# Val Acc   98.0667%
# Time Taken: 13.31 min
# Epoch:047/050 | Batch:000/210 |  Cost:0.0077
# Epoch:047/050 | Batch:050/210 |  Cost:0.0023
# Epoch:047/050 | Batch:100/210 |  Cost:0.0015
# Epoch:047/050 | Batch:150/210 |  Cost:0.0022
# Epoch:047/050 | Batch:200/210 |  Cost:0.0012
# Epoch:047/050 |
# Train Acc 100.0000%
# Val Acc   97.9333%
# Time Taken: 13.59 min
# Epoch:048/050 | Batch:000/210 |  Cost:0.0016
# Epoch:048/050 | Batch:050/210 |  Cost:0.0017
# Epoch:048/050 | Batch:100/210 |  Cost:0.0022
# Epoch:048/050 | Batch:150/210 |  Cost:0.0013
# Epoch:048/050 | Batch:200/210 |  Cost:0.0043
# Epoch:048/050 |
# Train Acc 99.9814%
# Val Acc   98.0000%
# Time Taken: 13.88 min
# Epoch:049/050 | Batch:000/210 |  Cost:0.0009
# Epoch:049/050 | Batch:050/210 |  Cost:0.0025
# Epoch:049/050 | Batch:100/210 |  Cost:0.0018
# Epoch:049/050 | Batch:150/210 |  Cost:0.0014
# Epoch:049/050 | Batch:200/210 |  Cost:0.0020
# Epoch:049/050 |
# Train Acc 100.0000%
# Val Acc   98.0667%
# Time Taken: 14.17 min
# Epoch:050/050 | Batch:000/210 |  Cost:0.0017
# Epoch:050/050 | Batch:050/210 |  Cost:0.0010
# Epoch:050/050 | Batch:100/210 |  Cost:0.0022
# Epoch:050/050 | Batch:150/210 |  Cost:0.0012
# Epoch:050/050 | Batch:200/210 |  Cost:0.0007
# Epoch:050/050 |
# Train Acc 100.0000%
# Val Acc   98.1833%
# Time Taken: 14.46 min
# Test Acc   97.8200%
# Total Time Taken: 14.49 min

# %%
plotTrainingLoss(miniBatchLoss=miniBatchLossList,
                   numEpoch=NUM_EPOCHS,
                   iterPerEpoch=len(trainLoader),
                   resultsDir=None,
                   avgIter=20)    #plotTrainingLoss(miniBatchLoss,numEpoch,iterPerEpoch,resultsDir=None,avgIter = 100)
plt.show()
plotAccuracy(trainAccList,validAccList)
plt.ylim([80,100])
plt.show()

# %% [markdown]
# ## DropOut With Probability 0.5

# %%
torch.manual_seed(RANDOM_SEED)
model = MultilayerPerceptron(numFeatures=28*28,
                             numHidden1=NUM_HIDDEN_1,
                             numHidden2=NUM_HIDDEN_2,
                             dropProba=0.5,
                             numClasses=10)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
miniBatchLossList, trainAccList, validAccList = modelTrainer(
    model1=model,
    numEpochs=NUM_EPOCHS,
    trainLoader=trainLoader,
    valLoader=validLoader,
    testLoader=testLoader,
    opt=optimizer,
    device=DEVICE)
# Out:
# Epoch:001/050 | Batch:000/210 |  Cost:2.4104
# Epoch:001/050 | Batch:050/210 |  Cost:1.0542
# Epoch:001/050 | Batch:100/210 |  Cost:0.8618
# Epoch:001/050 | Batch:150/210 |  Cost:0.7476
# Epoch:001/050 | Batch:200/210 |  Cost:0.6500
# Epoch:001/050 |
# Train Acc 90.9226%
# Val Acc   92.9167%
# Time Taken: 0.29 min
# Epoch:002/050 | Batch:000/210 |  Cost:0.5814
# Epoch:002/050 | Batch:050/210 |  Cost:0.6341
# Epoch:002/050 | Batch:100/210 |  Cost:0.7506
# Epoch:002/050 | Batch:150/210 |  Cost:0.6936
# Epoch:002/050 | Batch:200/210 |  Cost:0.5493
# Epoch:002/050 |
# Train Acc 92.5298%
# Val Acc   93.9000%
# Time Taken: 0.57 min
# Epoch:003/050 | Batch:000/210 |  Cost:0.3779
# Epoch:003/050 | Batch:050/210 |  Cost:0.5400
# Epoch:003/050 | Batch:100/210 |  Cost:0.5795
# Epoch:003/050 | Batch:150/210 |  Cost:0.4060
# Epoch:003/050 | Batch:200/210 |  Cost:0.5850
# Epoch:003/050 |
# Train Acc 93.6235%
# Val Acc   94.7667%
# Time Taken: 0.87 min
# Epoch:004/050 | Batch:000/210 |  Cost:0.4793
# Epoch:004/050 | Batch:050/210 |  Cost:0.3730
# Epoch:004/050 | Batch:100/210 |  Cost:0.5139
# Epoch:004/050 | Batch:150/210 |  Cost:0.5025
# Epoch:004/050 | Batch:200/210 |  Cost:0.4626
# Epoch:004/050 |
# Train Acc 94.2355%
# Val Acc   95.3167%
# Time Taken: 1.16 min
# Epoch:005/050 | Batch:000/210 |  Cost:0.4607
# Epoch:005/050 | Batch:050/210 |  Cost:0.3584
# Epoch:005/050 | Batch:100/210 |  Cost:0.4595
# Epoch:005/050 | Batch:150/210 |  Cost:0.4117
# Epoch:005/050 | Batch:200/210 |  Cost:0.5115
# Epoch:005/050 |
# Train Acc 94.7675%
# Val Acc   95.9000%
# Time Taken: 1.45 min
# Epoch:006/050 | Batch:000/210 |  Cost:0.4993
# Epoch:006/050 | Batch:050/210 |  Cost:0.5187
# Epoch:006/050 | Batch:100/210 |  Cost:0.4408
# Epoch:006/050 | Batch:150/210 |  Cost:0.3613
# Epoch:006/050 | Batch:200/210 |  Cost:0.4079
# Epoch:006/050 |
# Train Acc 94.8568%
# Val Acc   95.9333%
# Time Taken: 1.75 min
# Epoch:007/050 | Batch:000/210 |  Cost:0.4548
# Epoch:007/050 | Batch:050/210 |  Cost:0.3323
# Epoch:007/050 | Batch:100/210 |  Cost:0.2743
# Epoch:007/050 | Batch:150/210 |  Cost:0.4282
# Epoch:007/050 | Batch:200/210 |  Cost:0.3315
# Epoch:007/050 |
# Train Acc 95.2716%
# Val Acc   96.2833%
# Time Taken: 2.03 min
# Epoch:008/050 | Batch:000/210 |  Cost:0.3682
# Epoch:008/050 | Batch:050/210 |  Cost:0.3645
# Epoch:008/050 | Batch:100/210 |  Cost:0.3992
# Epoch:008/050 | Batch:150/210 |  Cost:0.4871
# Epoch:008/050 | Batch:200/210 |  Cost:0.4081
# Epoch:008/050 |
# Train Acc 95.4539%
# Val Acc   96.2167%
# Time Taken: 2.33 min
# Epoch:009/050 | Batch:000/210 |  Cost:0.3557
# Epoch:009/050 | Batch:050/210 |  Cost:0.4447
# Epoch:009/050 | Batch:100/210 |  Cost:0.3613
# Epoch:009/050 | Batch:150/210 |  Cost:0.5028
# Epoch:009/050 | Batch:200/210 |  Cost:0.3725
# Epoch:009/050 |
# Train Acc 95.7943%
# Val Acc   96.5667%
# Time Taken: 2.62 min
# Epoch:010/050 | Batch:000/210 |  Cost:0.3304
# Epoch:010/050 | Batch:050/210 |  Cost:0.3288
# Epoch:010/050 | Batch:100/210 |  Cost:0.3847
# Epoch:010/050 | Batch:150/210 |  Cost:0.3650
# Epoch:010/050 | Batch:200/210 |  Cost:0.3108
# Epoch:010/050 |
# Train Acc 95.9077%
# Val Acc   96.6500%
# Time Taken: 2.92 min
# Epoch:011/050 | Batch:000/210 |  Cost:0.2530
# Epoch:011/050 | Batch:050/210 |  Cost:0.3514
# Epoch:011/050 | Batch:100/210 |  Cost:0.3358
# Epoch:011/050 | Batch:150/210 |  Cost:0.3047
# Epoch:011/050 | Batch:200/210 |  Cost:0.2940
# Epoch:011/050 |
# Train Acc 96.2500%
# Val Acc   96.7833%
# Time Taken: 3.21 min
# Epoch:012/050 | Batch:000/210 |  Cost:0.3255
# Epoch:012/050 | Batch:050/210 |  Cost:0.4361
# Epoch:012/050 | Batch:100/210 |  Cost:0.3494
# Epoch:012/050 | Batch:150/210 |  Cost:0.3312
# Epoch:012/050 | Batch:200/210 |  Cost:0.4645
# Epoch:012/050 |
# Train Acc 96.4081%
# Val Acc   96.8833%
# Time Taken: 3.49 min
# Epoch:013/050 | Batch:000/210 |  Cost:0.3528
# Epoch:013/050 | Batch:050/210 |  Cost:0.3605
# Epoch:013/050 | Batch:100/210 |  Cost:0.3554
# Epoch:013/050 | Batch:150/210 |  Cost:0.3924
# Epoch:013/050 | Batch:200/210 |  Cost:0.2755
# Epoch:013/050 |
# Train Acc 96.5978%
# Val Acc   97.0500%
# Time Taken: 3.79 min
# Epoch:014/050 | Batch:000/210 |  Cost:0.3593
# Epoch:014/050 | Batch:050/210 |  Cost:0.3650
# Epoch:014/050 | Batch:100/210 |  Cost:0.3925
# Epoch:014/050 | Batch:150/210 |  Cost:0.2554
# Epoch:014/050 | Batch:200/210 |  Cost:0.3147
# Epoch:014/050 |
# Train Acc 96.5551%
# Val Acc   97.0500%
# Time Taken: 4.08 min
# Epoch:015/050 | Batch:000/210 |  Cost:0.3793
# Epoch:015/050 | Batch:050/210 |  Cost:0.2566
# Epoch:015/050 | Batch:100/210 |  Cost:0.4686
# Epoch:015/050 | Batch:150/210 |  Cost:0.2587
# Epoch:015/050 | Batch:200/210 |  Cost:0.2257
# Epoch:015/050 |
# Train Acc 96.6462%
# Val Acc   96.8333%
# Time Taken: 4.38 min
# Epoch:016/050 | Batch:000/210 |  Cost:0.2793
# Epoch:016/050 | Batch:050/210 |  Cost:0.2590
# Epoch:016/050 | Batch:100/210 |  Cost:0.2498
# Epoch:016/050 | Batch:150/210 |  Cost:0.4569
# Epoch:016/050 | Batch:200/210 |  Cost:0.2312
# Epoch:016/050 |
# Train Acc 96.8378%
# Val Acc   97.0667%
# Time Taken: 4.66 min
# Epoch:017/050 | Batch:000/210 |  Cost:0.3653
# Epoch:017/050 | Batch:050/210 |  Cost:0.2498
# Epoch:017/050 | Batch:100/210 |  Cost:0.3997
# Epoch:017/050 | Batch:150/210 |  Cost:0.2565
# Epoch:017/050 | Batch:200/210 |  Cost:0.3025
# Epoch:017/050 |
# Train Acc 96.9792%
# Val Acc   97.1833%
# Time Taken: 4.96 min
# Epoch:018/050 | Batch:000/210 |  Cost:0.3543
# Epoch:018/050 | Batch:050/210 |  Cost:0.3120
# Epoch:018/050 | Batch:100/210 |  Cost:0.2790
# Epoch:018/050 | Batch:150/210 |  Cost:0.3080
# Epoch:018/050 | Batch:200/210 |  Cost:0.2904
# Epoch:018/050 |
# Train Acc 97.0573%
# Val Acc   97.2167%
# Time Taken: 5.25 min
# Epoch:019/050 | Batch:000/210 |  Cost:0.3197
# Epoch:019/050 | Batch:050/210 |  Cost:0.3195
# Epoch:019/050 | Batch:100/210 |  Cost:0.3380
# Epoch:019/050 | Batch:150/210 |  Cost:0.4252
# Epoch:019/050 | Batch:200/210 |  Cost:0.2765
# Epoch:019/050 |
# Train Acc 97.0610%
# Val Acc   97.1000%
# Time Taken: 5.54 min
# Epoch:020/050 | Batch:000/210 |  Cost:0.2824
# Epoch:020/050 | Batch:050/210 |  Cost:0.2423
# Epoch:020/050 | Batch:100/210 |  Cost:0.2871
# Epoch:020/050 | Batch:150/210 |  Cost:0.3332
# Epoch:020/050 | Batch:200/210 |  Cost:0.3339
# Epoch:020/050 |
# Train Acc 97.0480%
# Val Acc   97.2167%
# Time Taken: 5.84 min
# Epoch:021/050 | Batch:000/210 |  Cost:0.3233
# Epoch:021/050 | Batch:050/210 |  Cost:0.2940
# Epoch:021/050 | Batch:100/210 |  Cost:0.2894
# Epoch:021/050 | Batch:150/210 |  Cost:0.3192
# Epoch:021/050 | Batch:200/210 |  Cost:0.3526
# Epoch:021/050 |
# Train Acc 97.0536%
# Val Acc   97.1833%
# Time Taken: 6.13 min
# Epoch:022/050 | Batch:000/210 |  Cost:0.3485
# Epoch:022/050 | Batch:050/210 |  Cost:0.3348
# Epoch:022/050 | Batch:100/210 |  Cost:0.2537
# Epoch:022/050 | Batch:150/210 |  Cost:0.3250
# Epoch:022/050 | Batch:200/210 |  Cost:0.3439
# Epoch:022/050 |
# Train Acc 97.2545%
# Val Acc   97.4000%
# Time Taken: 6.42 min
# Epoch:023/050 | Batch:000/210 |  Cost:0.2473
# Epoch:023/050 | Batch:050/210 |  Cost:0.2076
# Epoch:023/050 | Batch:100/210 |  Cost:0.4113
# Epoch:023/050 | Batch:150/210 |  Cost:0.2769
# Epoch:023/050 | Batch:200/210 |  Cost:0.3066
# Epoch:023/050 |
# Train Acc 97.1317%
# Val Acc   96.9833%
# Time Taken: 6.71 min
# Epoch:024/050 | Batch:000/210 |  Cost:0.2912
# Epoch:024/050 | Batch:050/210 |  Cost:0.2718
# Epoch:024/050 | Batch:100/210 |  Cost:0.2986
# Epoch:024/050 | Batch:150/210 |  Cost:0.3061
# Epoch:024/050 | Batch:200/210 |  Cost:0.2932
# Epoch:024/050 |
# Train Acc 97.2675%
# Val Acc   97.2667%
# Time Taken: 7.00 min
# Epoch:025/050 | Batch:000/210 |  Cost:0.3247
# Epoch:025/050 | Batch:050/210 |  Cost:0.2791
# Epoch:025/050 | Batch:100/210 |  Cost:0.2844
# Epoch:025/050 | Batch:150/210 |  Cost:0.2716
# Epoch:025/050 | Batch:200/210 |  Cost:0.2709
# Epoch:025/050 |
# Train Acc 97.3140%
# Val Acc   97.2667%
# Time Taken: 7.31 min
# Epoch:026/050 | Batch:000/210 |  Cost:0.2349
# Epoch:026/050 | Batch:050/210 |  Cost:0.2640
# Epoch:026/050 | Batch:100/210 |  Cost:0.2996
# Epoch:026/050 | Batch:150/210 |  Cost:0.2715
# Epoch:026/050 | Batch:200/210 |  Cost:0.3790
# Epoch:026/050 |
# Train Acc 97.4033%
# Val Acc   97.2167%
# Time Taken: 7.59 min
# Epoch:027/050 | Batch:000/210 |  Cost:0.2695
# Epoch:027/050 | Batch:050/210 |  Cost:0.2117
# Epoch:027/050 | Batch:100/210 |  Cost:0.2511
# Epoch:027/050 | Batch:150/210 |  Cost:0.2425
# Epoch:027/050 | Batch:200/210 |  Cost:0.1406
# Epoch:027/050 |
# Train Acc 97.4740%
# Val Acc   97.2667%
# Time Taken: 7.90 min
# Epoch:028/050 | Batch:000/210 |  Cost:0.2608
# Epoch:028/050 | Batch:050/210 |  Cost:0.4730
# Epoch:028/050 | Batch:100/210 |  Cost:0.2770
# Epoch:028/050 | Batch:150/210 |  Cost:0.3015
# Epoch:028/050 | Batch:200/210 |  Cost:0.2622
# Epoch:028/050 |
# Train Acc 97.3921%
# Val Acc   97.1167%
# Time Taken: 8.19 min
# Epoch:029/050 | Batch:000/210 |  Cost:0.2669
# Epoch:029/050 | Batch:050/210 |  Cost:0.2227
# Epoch:029/050 | Batch:100/210 |  Cost:0.2508
# Epoch:029/050 | Batch:150/210 |  Cost:0.2492
# Epoch:029/050 | Batch:200/210 |  Cost:0.4160
# Epoch:029/050 |
# Train Acc 97.5130%
# Val Acc   97.1333%
# Time Taken: 8.49 min
# Epoch:030/050 | Batch:000/210 |  Cost:0.2022
# Epoch:030/050 | Batch:050/210 |  Cost:0.3097
# Epoch:030/050 | Batch:100/210 |  Cost:0.2278
# Epoch:030/050 | Batch:150/210 |  Cost:0.2367
# Epoch:030/050 | Batch:200/210 |  Cost:0.2737
# Epoch:030/050 |
# Train Acc 97.5614%
# Val Acc   97.1833%
# Time Taken: 8.79 min
# Epoch:031/050 | Batch:000/210 |  Cost:0.3951
# Epoch:031/050 | Batch:050/210 |  Cost:0.3305
# Epoch:031/050 | Batch:100/210 |  Cost:0.3403
# Epoch:031/050 | Batch:150/210 |  Cost:0.2928
# Epoch:031/050 | Batch:200/210 |  Cost:0.2375
# Epoch:031/050 |
# Train Acc 97.6023%
# Val Acc   97.0500%
# Time Taken: 9.07 min
# Epoch:032/050 | Batch:000/210 |  Cost:0.2146
# Epoch:032/050 | Batch:050/210 |  Cost:0.2437
# Epoch:032/050 | Batch:100/210 |  Cost:0.2133
# Epoch:032/050 | Batch:150/210 |  Cost:0.2653
# Epoch:032/050 | Batch:200/210 |  Cost:0.2127
# Epoch:032/050 |
# Train Acc 97.6544%
# Val Acc   97.3167%
# Time Taken: 9.37 min
# Epoch:033/050 | Batch:000/210 |  Cost:0.3276
# Epoch:033/050 | Batch:050/210 |  Cost:0.2103
# Epoch:033/050 | Batch:100/210 |  Cost:0.1816
# Epoch:033/050 | Batch:150/210 |  Cost:0.3211
# Epoch:033/050 | Batch:200/210 |  Cost:0.2713
# Epoch:033/050 |
# Train Acc 97.6209%
# Val Acc   97.2000%
# Time Taken: 9.66 min
# Epoch:034/050 | Batch:000/210 |  Cost:0.2586
# Epoch:034/050 | Batch:050/210 |  Cost:0.2536
# Epoch:034/050 | Batch:100/210 |  Cost:0.2982
# Epoch:034/050 | Batch:150/210 |  Cost:0.2545
# Epoch:034/050 | Batch:200/210 |  Cost:0.2296
# Epoch:034/050 |
# Train Acc 97.8013%
# Val Acc   97.3500%
# Time Taken: 9.96 min
# Epoch:035/050 | Batch:000/210 |  Cost:0.2115
# Epoch:035/050 | Batch:050/210 |  Cost:0.3071
# Epoch:035/050 | Batch:100/210 |  Cost:0.1971
# Epoch:035/050 | Batch:150/210 |  Cost:0.2106
# Epoch:035/050 | Batch:200/210 |  Cost:0.3064
# Epoch:035/050 |
# Train Acc 97.7232%
# Val Acc   97.2333%
# Time Taken: 10.25 min
# Epoch:036/050 | Batch:000/210 |  Cost:0.2665
# Epoch:036/050 | Batch:050/210 |  Cost:0.2509
# Epoch:036/050 | Batch:100/210 |  Cost:0.2136
# Epoch:036/050 | Batch:150/210 |  Cost:0.2545
# Epoch:036/050 | Batch:200/210 |  Cost:0.2833
# Epoch:036/050 |
# Train Acc 97.7400%
# Val Acc   97.1167%
# Time Taken: 10.54 min
# Epoch:037/050 | Batch:000/210 |  Cost:0.3709
# Epoch:037/050 | Batch:050/210 |  Cost:0.3713
# Epoch:037/050 | Batch:100/210 |  Cost:0.2166
# Epoch:037/050 | Batch:150/210 |  Cost:0.2593
# Epoch:037/050 | Batch:200/210 |  Cost:0.2232
# Epoch:037/050 |
# Train Acc 97.7548%
# Val Acc   97.2333%
# Time Taken: 10.85 min
# Epoch:038/050 | Batch:000/210 |  Cost:0.2915
# Epoch:038/050 | Batch:050/210 |  Cost:0.1870
# Epoch:038/050 | Batch:100/210 |  Cost:0.2583
# Epoch:038/050 | Batch:150/210 |  Cost:0.2408
# Epoch:038/050 | Batch:200/210 |  Cost:0.3099
# Epoch:038/050 |
# Train Acc 97.8144%
# Val Acc   97.2667%
# Time Taken: 11.14 min
# Epoch:039/050 | Batch:000/210 |  Cost:0.2729
# Epoch:039/050 | Batch:050/210 |  Cost:0.3449
# Epoch:039/050 | Batch:100/210 |  Cost:0.2830
# Epoch:039/050 | Batch:150/210 |  Cost:0.2513
# Epoch:039/050 | Batch:200/210 |  Cost:0.2597
# Epoch:039/050 |
# Train Acc 97.7734%
# Val Acc   97.3000%
# Time Taken: 11.44 min
# Epoch:040/050 | Batch:000/210 |  Cost:0.2704
# Epoch:040/050 | Batch:050/210 |  Cost:0.2630
# Epoch:040/050 | Batch:100/210 |  Cost:0.2275
# Epoch:040/050 | Batch:150/210 |  Cost:0.3121
# Epoch:040/050 | Batch:200/210 |  Cost:0.1676
# Epoch:040/050 |
# Train Acc 97.7679%
# Val Acc   97.3167%
# Time Taken: 11.72 min
# Epoch:041/050 | Batch:000/210 |  Cost:0.3242
# Epoch:041/050 | Batch:050/210 |  Cost:0.3646
# Epoch:041/050 | Batch:100/210 |  Cost:0.1956
# Epoch:041/050 | Batch:150/210 |  Cost:0.2343
# Epoch:041/050 | Batch:200/210 |  Cost:0.2257
# Epoch:041/050 |
# Train Acc 97.8553%
# Val Acc   97.3667%
# Time Taken: 12.01 min
# Epoch:042/050 | Batch:000/210 |  Cost:0.1560
# Epoch:042/050 | Batch:050/210 |  Cost:0.3725
# Epoch:042/050 | Batch:100/210 |  Cost:0.3319
# Epoch:042/050 | Batch:150/210 |  Cost:0.2039
# Epoch:042/050 | Batch:200/210 |  Cost:0.2005
# Epoch:042/050 |
# Train Acc 97.8776%
# Val Acc   97.2167%
# Time Taken: 12.32 min
# Epoch:043/050 | Batch:000/210 |  Cost:0.2846
# Epoch:043/050 | Batch:050/210 |  Cost:0.2541
# Epoch:043/050 | Batch:100/210 |  Cost:0.1720
# Epoch:043/050 | Batch:150/210 |  Cost:0.2148
# Epoch:043/050 | Batch:200/210 |  Cost:0.3805
# Epoch:043/050 |
# Train Acc 97.9483%
# Val Acc   97.1667%
# Time Taken: 12.60 min
# Epoch:044/050 | Batch:000/210 |  Cost:0.2075
# Epoch:044/050 | Batch:050/210 |  Cost:0.2125
# Epoch:044/050 | Batch:100/210 |  Cost:0.2843
# Epoch:044/050 | Batch:150/210 |  Cost:0.2175
# Epoch:044/050 | Batch:200/210 |  Cost:0.2927
# Epoch:044/050 |
# Train Acc 97.8906%
# Val Acc   97.1333%
# Time Taken: 12.90 min
# Epoch:045/050 | Batch:000/210 |  Cost:0.3067
# Epoch:045/050 | Batch:050/210 |  Cost:0.1535
# Epoch:045/050 | Batch:100/210 |  Cost:0.2310
# Epoch:045/050 | Batch:150/210 |  Cost:0.1815
# Epoch:045/050 | Batch:200/210 |  Cost:0.2598
# Epoch:045/050 |
# Train Acc 97.9874%
# Val Acc   97.3000%
# Time Taken: 13.19 min
# Epoch:046/050 | Batch:000/210 |  Cost:0.3004
# Epoch:046/050 | Batch:050/210 |  Cost:0.1896
# Epoch:046/050 | Batch:100/210 |  Cost:0.4239
# Epoch:046/050 | Batch:150/210 |  Cost:0.2469
# Epoch:046/050 | Batch:200/210 |  Cost:0.2329
# Epoch:046/050 |
# Train Acc 97.9092%
# Val Acc   97.3000%
# Time Taken: 13.48 min
# Epoch:047/050 | Batch:000/210 |  Cost:0.1868
# Epoch:047/050 | Batch:050/210 |  Cost:0.2030
# Epoch:047/050 | Batch:100/210 |  Cost:0.3384
# Epoch:047/050 | Batch:150/210 |  Cost:0.2365
# Epoch:047/050 | Batch:200/210 |  Cost:0.2547
# Epoch:047/050 |
# Train Acc 97.9297%
# Val Acc   97.3167%
# Time Taken: 13.78 min
# Epoch:048/050 | Batch:000/210 |  Cost:0.2473
# Epoch:048/050 | Batch:050/210 |  Cost:0.2361
# Epoch:048/050 | Batch:100/210 |  Cost:0.4161
# Epoch:048/050 | Batch:150/210 |  Cost:0.3683
# Epoch:048/050 | Batch:200/210 |  Cost:0.2183
# Epoch:048/050 |
# Train Acc 98.0264%
# Val Acc   97.4000%
# Time Taken: 14.07 min
# Epoch:049/050 | Batch:000/210 |  Cost:0.2502
# Epoch:049/050 | Batch:050/210 |  Cost:0.2125
# Epoch:049/050 | Batch:100/210 |  Cost:0.2130
# Epoch:049/050 | Batch:150/210 |  Cost:0.2142
# Epoch:049/050 | Batch:200/210 |  Cost:0.1749
# Epoch:049/050 |
# Train Acc 98.0729%
# Val Acc   97.4333%
# Time Taken: 14.38 min
# Epoch:050/050 | Batch:000/210 |  Cost:0.1586
# Epoch:050/050 | Batch:050/210 |  Cost:0.2493
# Epoch:050/050 | Batch:100/210 |  Cost:0.2666
# Epoch:050/050 | Batch:150/210 |  Cost:0.2646
# Epoch:050/050 | Batch:200/210 |  Cost:0.2980
# Epoch:050/050 |
# Train Acc 98.0413%
# Val Acc   97.1500%
# Time Taken: 14.67 min
# Test Acc   96.8200%
# Total Time Taken: 14.69 min

# %%
plotTrainingLoss(miniBatchLoss=miniBatchLossList,
                   numEpoch=NUM_EPOCHS,
                   iterPerEpoch=len(trainLoader),
                   resultsDir=None,
                   avgIter=20)    #plotTrainingLoss(miniBatchLoss,numEpoch,iterPerEpoch,resultsDir=None,avgIter = 100)
plt.show()
plotAccuracy(trainAccList,validAccList)
plt.ylim([80,100])
plt.show()
