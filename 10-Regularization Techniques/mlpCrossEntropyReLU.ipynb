# %% [raw]
# #MLP with Softmax and Cross Entropy

# %% [markdown]
# ##Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch
# %matplotlib inline

# %%
import time
import numpy as np
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch

# %% [markdown]
# ##Settings and Device

# %%
randomSeed = 1
batchSize = 100
numEpochs = 100

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ##DataLoader

# %%
trainDataset = datasets.MNIST(root='data',
                              train=True,
                              transform=transforms.ToTensor(),
                              download = True)

testDataset = datasets.MNIST(root='data',
                             train=False,
                             transform=transforms.ToTensor())

trainLoader = DataLoader(dataset=trainDataset,
                         batch_size=batchSize,
                         shuffle=True)


testLoader = DataLoader(dataset=testDataset,
                         batch_size=batchSize,
                         shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 132068980.42it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 56791230.11it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 38743404.37it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 6377813.45it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
for images,labels in trainLoader:
  print('Image batch dim',images.shape)
  print('Label batch dim',labels.shape)
  break
# Out:
# Image batch dim torch.Size([100, 1, 28, 28])
# Label batch dim torch.Size([100])

# %%
trainLoader

# %% [markdown]
# ##One Hot Encoding

# %%
def toOneHot(y,nClasses):
  yOneHot = torch.FloatTensor(y.size(0),nClasses)
  yOneHot.zero_()
  tmp = y.view(-1,1).long().to(torch.device('cpu'))
  yOneHot.scatter_(1,tmp,1).float()
  return yOneHot

# %% [markdown]
# ##Model

# %%
class mlpSoftmax(torch.nn.Module):

  def __init__(self,numFeatures,numHidden,numClasses,dropProba):
    super(mlpSoftmax,self).__init__()

    self.numClasses = numClasses

#     self.linearLayer = torch.nn.Linear(numFeatures,numHidden)
#     self.linearLayer.weight.detach().normal_(0,0.1)
#     self.linearLayer.bias.detach().normal_(0)

#     self.linearOut = torch.nn.Linear(numHidden,numClasses)
#     self.linearOut.weight.detach().normal_(0,0.1)
#     self.linearOut.bias.detach().normal_(0)
    
    self.myNetwork = torch.nn.Sequential(
        # 1st hidden layer
        torch.nn.Flatten(),
        torch.nn.Linear(numFeatures, numHidden),
        torch.nn.ReLU(),
        torch.nn.Dropout(dropProba),
        #2nd hidden layer
        torch.nn.Linear(numHidden,numClasses),
        torch.nn.ReLU(),
        torch.nn.Dropout(dropProba)
    )
#     self.my_network = torch.nn.Sequential(
#             # 1st hidden layer
#             torch.nn.Flatten(),
#             torch.nn.Linear(num_features, num_hidden_1),
#             torch.nn.ReLU(),
#             torch.nn.Dropout(drop_proba),
#             # 2nd hidden layer
#             torch.nn.Linear(num_hidden_1, num_hidden_2),
#             torch.nn.ReLU(),
#             torch.nn.Dropout(drop_proba),
#             # output layer
#             torch.nn.Linear(num_hidden_2, num_classes)
#         )

  def forward(self,x):
#     out = self.linearLayer(x)
#     out = torch.sigmoid(out)
#     logits = self.linearOut(out)
    logits = self.myNetwork(x)
    return logits

# %% [markdown]
# ##Model Initialization

# %%
torch.manual_seed(randomSeed)

# %%
model = mlpSoftmax(numFeatures=784,numHidden=100,numClasses=10,dropProba= 0)
model.to(DEVICE)
# Out:
# mlpSoftmax(
#   (myNetwork): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=100, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0, inplace=False)
#     (4): Linear(in_features=100, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0, inplace=False)
#   )
# )

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.1)

# %%
def computeLoss(net,dataLoader):
  totalLoss = 0.
  with torch.no_grad():
      for cnt , (features,targets) in enumerate(dataLoader):
        features = features.view(-1,28*28)
        # targets = targets.view(-1).float()
        targets = toOneHot(targets,net.numClasses)
        logits = model(features)
        loss = F.cross_entropy(logits,targets)
        totalLoss+=loss
      return totalLoss/cnt

# %% [markdown]
# ## Training

# %%
startTime = time.time()
miniBatchCost = []
epochCost = []
for e in range(numEpochs):
  model.train()
  for batchIDx, (features,targets) in enumerate(trainLoader):
    features = features.view(-1,28*28)
    # targets = targets.view(-1).float()
    targets = toOneHot(targets,model.numClasses)
    logits = model(features)
    cost = F.cross_entropy(logits,targets)
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    miniBatchCost.append(cost.item())
    if(not batchIDx % 50):
      print("Epoch %03d/%03d | Batch %03d/%03d | Cost: %.4f" % (e+1,numEpochs,batchIDx,len(trainLoader),cost.item()))
  epoCost = computeLoss(model,trainLoader)
  print("Epoch %03d/%03d | Cost: %.4f" % (e+1,numEpochs,epoCost))
  print("Time: %.2f min" %((time.time()-startTime)/60))
  epochCost.append(epoCost)
print("Total Time: %.2f min" %((time.time()-startTime)/60))
# Out:
# Epoch 001/100 | Batch 000/600 | Cost: 2.3083
# Epoch 001/100 | Batch 050/600 | Cost: 1.6498
# Epoch 001/100 | Batch 100/600 | Cost: 0.9908
# Epoch 001/100 | Batch 150/600 | Cost: 1.0400
# Epoch 001/100 | Batch 200/600 | Cost: 0.9137
# Epoch 001/100 | Batch 250/600 | Cost: 0.8701
# Epoch 001/100 | Batch 300/600 | Cost: 0.9602
# Epoch 001/100 | Batch 350/600 | Cost: 0.7581
# Epoch 001/100 | Batch 400/600 | Cost: 0.9432
# Epoch 001/100 | Batch 450/600 | Cost: 0.8202
# Epoch 001/100 | Batch 500/600 | Cost: 1.0469
# Epoch 001/100 | Batch 550/600 | Cost: 0.7658
# Epoch 001/100 | Cost: 0.7737
# Time: 0.27 min
# Epoch 002/100 | Batch 000/600 | Cost: 0.6343
# Epoch 002/100 | Batch 050/600 | Cost: 1.0256
# Epoch 002/100 | Batch 100/600 | Cost: 0.6904
# Epoch 002/100 | Batch 150/600 | Cost: 0.6376
# Epoch 002/100 | Batch 200/600 | Cost: 0.9459
# Epoch 002/100 | Batch 250/600 | Cost: 0.7229
# Epoch 002/100 | Batch 300/600 | Cost: 1.0124
# Epoch 002/100 | Batch 350/600 | Cost: 0.9161
# Epoch 002/100 | Batch 400/600 | Cost: 0.7124
# Epoch 002/100 | Batch 450/600 | Cost: 0.8879
# Epoch 002/100 | Batch 500/600 | Cost: 0.6527
# Epoch 002/100 | Batch 550/600 | Cost: 0.7171
# Epoch 002/100 | Cost: 0.7076
# Time: 0.53 min
# Epoch 003/100 | Batch 000/600 | Cost: 0.6214
# Epoch 003/100 | Batch 050/600 | Cost: 0.4366
# Epoch 003/100 | Batch 100/600 | Cost: 0.5810
# Epoch 003/100 | Batch 150/600 | Cost: 0.6052
# Epoch 003/100 | Batch 200/600 | Cost: 0.7359
# Epoch 003/100 | Batch 250/600 | Cost: 0.5416
# Epoch 003/100 | Batch 300/600 | Cost: 0.7385
# Epoch 003/100 | Batch 350/600 | Cost: 0.8564
# Epoch 003/100 | Batch 400/600 | Cost: 0.5508
# Epoch 003/100 | Batch 450/600 | Cost: 0.8923
# Epoch 003/100 | Batch 500/600 | Cost: 0.7135
# Epoch 003/100 | Batch 550/600 | Cost: 0.5888
# Epoch 003/100 | Cost: 0.4636
# Time: 0.80 min
# Epoch 004/100 | Batch 000/600 | Cost: 0.8078
# Epoch 004/100 | Batch 050/600 | Cost: 0.4238
# Epoch 004/100 | Batch 100/600 | Cost: 0.3865
# Epoch 004/100 | Batch 150/600 | Cost: 0.4791
# Epoch 004/100 | Batch 200/600 | Cost: 0.3893
# Epoch 004/100 | Batch 250/600 | Cost: 0.3932
# Epoch 004/100 | Batch 300/600 | Cost: 0.4471
# Epoch 004/100 | Batch 350/600 | Cost: 0.4069
# Epoch 004/100 | Batch 400/600 | Cost: 0.3015
# Epoch 004/100 | Batch 450/600 | Cost: 0.3897
# Epoch 004/100 | Batch 500/600 | Cost: 0.4989
# Epoch 004/100 | Batch 550/600 | Cost: 0.3109
# Epoch 004/100 | Cost: 0.3994
# Time: 1.07 min
# Epoch 005/100 | Batch 000/600 | Cost: 0.3538
# Epoch 005/100 | Batch 050/600 | Cost: 0.5334
# Epoch 005/100 | Batch 100/600 | Cost: 0.2599
# Epoch 005/100 | Batch 150/600 | Cost: 0.3466
# Epoch 005/100 | Batch 200/600 | Cost: 0.3181
# Epoch 005/100 | Batch 250/600 | Cost: 0.2972
# Epoch 005/100 | Batch 300/600 | Cost: 0.5577
# Epoch 005/100 | Batch 350/600 | Cost: 0.3492
# Epoch 005/100 | Batch 400/600 | Cost: 0.4199
# Epoch 005/100 | Batch 450/600 | Cost: 0.3434
# Epoch 005/100 | Batch 500/600 | Cost: 0.3443
# Epoch 005/100 | Batch 550/600 | Cost: 0.3920
# Epoch 005/100 | Cost: 0.3725
# Time: 1.33 min
# Epoch 006/100 | Batch 000/600 | Cost: 0.5421
# Epoch 006/100 | Batch 050/600 | Cost: 0.3666
# Epoch 006/100 | Batch 100/600 | Cost: 0.3484
# Epoch 006/100 | Batch 150/600 | Cost: 0.3915
# Epoch 006/100 | Batch 200/600 | Cost: 0.3420
# Epoch 006/100 | Batch 250/600 | Cost: 0.5483
# Epoch 006/100 | Batch 300/600 | Cost: 0.3702
# Epoch 006/100 | Batch 350/600 | Cost: 0.4229
# Epoch 006/100 | Batch 400/600 | Cost: 0.3683
# Epoch 006/100 | Batch 450/600 | Cost: 0.3431
# Epoch 006/100 | Batch 500/600 | Cost: 0.4924
# Epoch 006/100 | Batch 550/600 | Cost: 0.4511
# Epoch 006/100 | Cost: 0.3551
# Time: 1.60 min
# Epoch 007/100 | Batch 000/600 | Cost: 0.3617
# Epoch 007/100 | Batch 050/600 | Cost: 0.5307
# Epoch 007/100 | Batch 100/600 | Cost: 0.3562
# Epoch 007/100 | Batch 150/600 | Cost: 0.3488
# Epoch 007/100 | Batch 200/600 | Cost: 0.1554
# Epoch 007/100 | Batch 250/600 | Cost: 0.2579
# Epoch 007/100 | Batch 300/600 | Cost: 0.3517
# Epoch 007/100 | Batch 350/600 | Cost: 0.2336
# Epoch 007/100 | Batch 400/600 | Cost: 0.3808
# Epoch 007/100 | Batch 450/600 | Cost: 0.2815
# Epoch 007/100 | Batch 500/600 | Cost: 0.3371
# Epoch 007/100 | Batch 550/600 | Cost: 0.2990
# Epoch 007/100 | Cost: 0.3437
# Time: 1.86 min
# Epoch 008/100 | Batch 000/600 | Cost: 0.3017
# Epoch 008/100 | Batch 050/600 | Cost: 0.2742
# Epoch 008/100 | Batch 100/600 | Cost: 0.5515
# Epoch 008/100 | Batch 150/600 | Cost: 0.2438
# Epoch 008/100 | Batch 200/600 | Cost: 0.3134
# Epoch 008/100 | Batch 250/600 | Cost: 0.2712
# Epoch 008/100 | Batch 300/600 | Cost: 0.4497
# Epoch 008/100 | Batch 350/600 | Cost: 0.2688
# Epoch 008/100 | Batch 400/600 | Cost: 0.3425
# Epoch 008/100 | Batch 450/600 | Cost: 0.3943
# Epoch 008/100 | Batch 500/600 | Cost: 0.2568
# Epoch 008/100 | Batch 550/600 | Cost: 0.2939
# Epoch 008/100 | Cost: 0.3295
# Time: 2.12 min
# Epoch 009/100 | Batch 000/600 | Cost: 0.3998
# Epoch 009/100 | Batch 050/600 | Cost: 0.3059
# Epoch 009/100 | Batch 100/600 | Cost: 0.4505
# Epoch 009/100 | Batch 150/600 | Cost: 0.3851
# Epoch 009/100 | Batch 200/600 | Cost: 0.0771
# Epoch 009/100 | Batch 250/600 | Cost: 0.2754
# Epoch 009/100 | Batch 300/600 | Cost: 0.2567
# Epoch 009/100 | Batch 350/600 | Cost: 0.1160
# Epoch 009/100 | Batch 400/600 | Cost: 0.1083
# Epoch 009/100 | Batch 450/600 | Cost: 0.0775
# Epoch 009/100 | Batch 500/600 | Cost: 0.1093
# Epoch 009/100 | Batch 550/600 | Cost: 0.1057
# Epoch 009/100 | Cost: 0.1009
# Time: 2.39 min
# Epoch 010/100 | Batch 000/600 | Cost: 0.1023
# Epoch 010/100 | Batch 050/600 | Cost: 0.1303
# Epoch 010/100 | Batch 100/600 | Cost: 0.1223
# Epoch 010/100 | Batch 150/600 | Cost: 0.0738
# Epoch 010/100 | Batch 200/600 | Cost: 0.1072
# Epoch 010/100 | Batch 250/600 | Cost: 0.0632
# Epoch 010/100 | Batch 300/600 | Cost: 0.1006
# Epoch 010/100 | Batch 350/600 | Cost: 0.1657
# Epoch 010/100 | Batch 400/600 | Cost: 0.1758
# Epoch 010/100 | Batch 450/600 | Cost: 0.0754
# Epoch 010/100 | Batch 500/600 | Cost: 0.1278
# Epoch 010/100 | Batch 550/600 | Cost: 0.1488
# Epoch 010/100 | Cost: 0.0919
# Time: 2.66 min
# Epoch 011/100 | Batch 000/600 | Cost: 0.0810
# Epoch 011/100 | Batch 050/600 | Cost: 0.1625
# Epoch 011/100 | Batch 100/600 | Cost: 0.0478
# Epoch 011/100 | Batch 150/600 | Cost: 0.0822
# Epoch 011/100 | Batch 200/600 | Cost: 0.0881
# Epoch 011/100 | Batch 250/600 | Cost: 0.0761
# Epoch 011/100 | Batch 300/600 | Cost: 0.1237
# Epoch 011/100 | Batch 350/600 | Cost: 0.0995
# Epoch 011/100 | Batch 400/600 | Cost: 0.1315
# Epoch 011/100 | Batch 450/600 | Cost: 0.0555
# Epoch 011/100 | Batch 500/600 | Cost: 0.0635
# Epoch 011/100 | Batch 550/600 | Cost: 0.1008
# Epoch 011/100 | Cost: 0.0857
# Time: 2.93 min
# Epoch 012/100 | Batch 000/600 | Cost: 0.0728
# Epoch 012/100 | Batch 050/600 | Cost: 0.1722
# Epoch 012/100 | Batch 100/600 | Cost: 0.0295
# Epoch 012/100 | Batch 150/600 | Cost: 0.0731
# Epoch 012/100 | Batch 200/600 | Cost: 0.0716
# Epoch 012/100 | Batch 250/600 | Cost: 0.0921
# Epoch 012/100 | Batch 300/600 | Cost: 0.0423
# Epoch 012/100 | Batch 350/600 | Cost: 0.2086
# Epoch 012/100 | Batch 400/600 | Cost: 0.0765
# Epoch 012/100 | Batch 450/600 | Cost: 0.0709
# Epoch 012/100 | Batch 500/600 | Cost: 0.0778
# Epoch 012/100 | Batch 550/600 | Cost: 0.1046
# Epoch 012/100 | Cost: 0.0776
# Time: 3.19 min
# Epoch 013/100 | Batch 000/600 | Cost: 0.0453
# Epoch 013/100 | Batch 050/600 | Cost: 0.0495
# Epoch 013/100 | Batch 100/600 | Cost: 0.0449
# Epoch 013/100 | Batch 150/600 | Cost: 0.0592
# Epoch 013/100 | Batch 200/600 | Cost: 0.1193
# Epoch 013/100 | Batch 250/600 | Cost: 0.0208
# Epoch 013/100 | Batch 300/600 | Cost: 0.0437
# Epoch 013/100 | Batch 350/600 | Cost: 0.0419
# Epoch 013/100 | Batch 400/600 | Cost: 0.2406
# Epoch 013/100 | Batch 450/600 | Cost: 0.0175
# Epoch 013/100 | Batch 500/600 | Cost: 0.1222
# Epoch 013/100 | Batch 550/600 | Cost: 0.0872
# Epoch 013/100 | Cost: 0.0697
# Time: 3.45 min
# Epoch 014/100 | Batch 000/600 | Cost: 0.1226
# Epoch 014/100 | Batch 050/600 | Cost: 0.0903
# Epoch 014/100 | Batch 100/600 | Cost: 0.0442
# Epoch 014/100 | Batch 150/600 | Cost: 0.1421
# Epoch 014/100 | Batch 200/600 | Cost: 0.0804
# Epoch 014/100 | Batch 250/600 | Cost: 0.0952
# Epoch 014/100 | Batch 300/600 | Cost: 0.0814
# Epoch 014/100 | Batch 350/600 | Cost: 0.0935
# Epoch 014/100 | Batch 400/600 | Cost: 0.0697
# Epoch 014/100 | Batch 450/600 | Cost: 0.1430
# Epoch 014/100 | Batch 500/600 | Cost: 0.0907
# Epoch 014/100 | Batch 550/600 | Cost: 0.0712
# Epoch 014/100 | Cost: 0.0668
# Time: 3.72 min
# Epoch 015/100 | Batch 000/600 | Cost: 0.0473
# Epoch 015/100 | Batch 050/600 | Cost: 0.0740
# Epoch 015/100 | Batch 100/600 | Cost: 0.0584
# Epoch 015/100 | Batch 150/600 | Cost: 0.0591
# Epoch 015/100 | Batch 200/600 | Cost: 0.0847
# Epoch 015/100 | Batch 250/600 | Cost: 0.0398
# Epoch 015/100 | Batch 300/600 | Cost: 0.1304
# Epoch 015/100 | Batch 350/600 | Cost: 0.0654
# Epoch 015/100 | Batch 400/600 | Cost: 0.0758
# Epoch 015/100 | Batch 450/600 | Cost: 0.0951
# Epoch 015/100 | Batch 500/600 | Cost: 0.0665
# Epoch 015/100 | Batch 550/600 | Cost: 0.1197
# Epoch 015/100 | Cost: 0.0622
# Time: 3.99 min
# Epoch 016/100 | Batch 000/600 | Cost: 0.0626
# Epoch 016/100 | Batch 050/600 | Cost: 0.0490
# Epoch 016/100 | Batch 100/600 | Cost: 0.0585
# Epoch 016/100 | Batch 150/600 | Cost: 0.0478
# Epoch 016/100 | Batch 200/600 | Cost: 0.0390
# Epoch 016/100 | Batch 250/600 | Cost: 0.0476
# Epoch 016/100 | Batch 300/600 | Cost: 0.0663
# Epoch 016/100 | Batch 350/600 | Cost: 0.0359
# Epoch 016/100 | Batch 400/600 | Cost: 0.0949
# Epoch 016/100 | Batch 450/600 | Cost: 0.0376
# Epoch 016/100 | Batch 500/600 | Cost: 0.0496
# Epoch 016/100 | Batch 550/600 | Cost: 0.0417
# Epoch 016/100 | Cost: 0.0594
# Time: 4.26 min
# Epoch 017/100 | Batch 000/600 | Cost: 0.0700
# Epoch 017/100 | Batch 050/600 | Cost: 0.0818
# Epoch 017/100 | Batch 100/600 | Cost: 0.0163
# Epoch 017/100 | Batch 150/600 | Cost: 0.0200
# Epoch 017/100 | Batch 200/600 | Cost: 0.0837
# Epoch 017/100 | Batch 250/600 | Cost: 0.0192
# Epoch 017/100 | Batch 300/600 | Cost: 0.0907
# Epoch 017/100 | Batch 350/600 | Cost: 0.0520
# Epoch 017/100 | Batch 400/600 | Cost: 0.0677
# Epoch 017/100 | Batch 450/600 | Cost: 0.0338
# Epoch 017/100 | Batch 500/600 | Cost: 0.0323
# Epoch 017/100 | Batch 550/600 | Cost: 0.0759
# Epoch 017/100 | Cost: 0.0567
# Time: 4.52 min
# Epoch 018/100 | Batch 000/600 | Cost: 0.0622
# Epoch 018/100 | Batch 050/600 | Cost: 0.0233
# Epoch 018/100 | Batch 100/600 | Cost: 0.0420
# Epoch 018/100 | Batch 150/600 | Cost: 0.0301
# Epoch 018/100 | Batch 200/600 | Cost: 0.0244
# Epoch 018/100 | Batch 250/600 | Cost: 0.0507
# Epoch 018/100 | Batch 300/600 | Cost: 0.0163
# Epoch 018/100 | Batch 350/600 | Cost: 0.0420
# Epoch 018/100 | Batch 400/600 | Cost: 0.0821
# Epoch 018/100 | Batch 450/600 | Cost: 0.0353
# Epoch 018/100 | Batch 500/600 | Cost: 0.0294
# Epoch 018/100 | Batch 550/600 | Cost: 0.1231
# Epoch 018/100 | Cost: 0.0527
# Time: 4.79 min
# Epoch 019/100 | Batch 000/600 | Cost: 0.0747
# Epoch 019/100 | Batch 050/600 | Cost: 0.0442
# Epoch 019/100 | Batch 100/600 | Cost: 0.0521
# Epoch 019/100 | Batch 150/600 | Cost: 0.0551
# Epoch 019/100 | Batch 200/600 | Cost: 0.0577
# Epoch 019/100 | Batch 250/600 | Cost: 0.0643
# Epoch 019/100 | Batch 300/600 | Cost: 0.0217
# Epoch 019/100 | Batch 350/600 | Cost: 0.0575
# Epoch 019/100 | Batch 400/600 | Cost: 0.0816
# Epoch 019/100 | Batch 450/600 | Cost: 0.0305
# Epoch 019/100 | Batch 500/600 | Cost: 0.1321
# Epoch 019/100 | Batch 550/600 | Cost: 0.0349
# Epoch 019/100 | Cost: 0.0491
# Time: 5.05 min
# Epoch 020/100 | Batch 000/600 | Cost: 0.0836
# Epoch 020/100 | Batch 050/600 | Cost: 0.0540
# Epoch 020/100 | Batch 100/600 | Cost: 0.0261
# Epoch 020/100 | Batch 150/600 | Cost: 0.0228
# Epoch 020/100 | Batch 200/600 | Cost: 0.0744
# Epoch 020/100 | Batch 250/600 | Cost: 0.1975
# Epoch 020/100 | Batch 300/600 | Cost: 0.0259
# Epoch 020/100 | Batch 350/600 | Cost: 0.0476
# Epoch 020/100 | Batch 400/600 | Cost: 0.0865
# Epoch 020/100 | Batch 450/600 | Cost: 0.0226
# Epoch 020/100 | Batch 500/600 | Cost: 0.0170
# Epoch 020/100 | Batch 550/600 | Cost: 0.0416
# Epoch 020/100 | Cost: 0.0454
# Time: 5.31 min
# Epoch 021/100 | Batch 000/600 | Cost: 0.0217
# Epoch 021/100 | Batch 050/600 | Cost: 0.0931
# Epoch 021/100 | Batch 100/600 | Cost: 0.0411
# Epoch 021/100 | Batch 150/600 | Cost: 0.0301
# Epoch 021/100 | Batch 200/600 | Cost: 0.0386
# Epoch 021/100 | Batch 250/600 | Cost: 0.0616
# Epoch 021/100 | Batch 300/600 | Cost: 0.0314
# Epoch 021/100 | Batch 350/600 | Cost: 0.0681
# Epoch 021/100 | Batch 400/600 | Cost: 0.0383
# Epoch 021/100 | Batch 450/600 | Cost: 0.0319
# Epoch 021/100 | Batch 500/600 | Cost: 0.0416
# Epoch 021/100 | Batch 550/600 | Cost: 0.0852
# Epoch 021/100 | Cost: 0.0426
# Time: 5.57 min
# Epoch 022/100 | Batch 000/600 | Cost: 0.0272
# Epoch 022/100 | Batch 050/600 | Cost: 0.0491
# Epoch 022/100 | Batch 100/600 | Cost: 0.0379
# Epoch 022/100 | Batch 150/600 | Cost: 0.0229
# Epoch 022/100 | Batch 200/600 | Cost: 0.0129
# Epoch 022/100 | Batch 250/600 | Cost: 0.0194
# Epoch 022/100 | Batch 300/600 | Cost: 0.0365
# Epoch 022/100 | Batch 350/600 | Cost: 0.0393
# Epoch 022/100 | Batch 400/600 | Cost: 0.1241
# Epoch 022/100 | Batch 450/600 | Cost: 0.0476
# Epoch 022/100 | Batch 500/600 | Cost: 0.0270
# Epoch 022/100 | Batch 550/600 | Cost: 0.0350
# Epoch 022/100 | Cost: 0.0409
# Time: 5.83 min
# Epoch 023/100 | Batch 000/600 | Cost: 0.0290
# Epoch 023/100 | Batch 050/600 | Cost: 0.0341
# Epoch 023/100 | Batch 100/600 | Cost: 0.0183
# Epoch 023/100 | Batch 150/600 | Cost: 0.0336
# Epoch 023/100 | Batch 200/600 | Cost: 0.0389
# Epoch 023/100 | Batch 250/600 | Cost: 0.0520
# Epoch 023/100 | Batch 300/600 | Cost: 0.0165
# Epoch 023/100 | Batch 350/600 | Cost: 0.0109
# Epoch 023/100 | Batch 400/600 | Cost: 0.0410
# Epoch 023/100 | Batch 450/600 | Cost: 0.0272
# Epoch 023/100 | Batch 500/600 | Cost: 0.0349
# Epoch 023/100 | Batch 550/600 | Cost: 0.0377
# Epoch 023/100 | Cost: 0.0378
# Time: 6.09 min
# Epoch 024/100 | Batch 000/600 | Cost: 0.0658
# Epoch 024/100 | Batch 050/600 | Cost: 0.1378
# Epoch 024/100 | Batch 100/600 | Cost: 0.0186
# Epoch 024/100 | Batch 150/600 | Cost: 0.0297
# Epoch 024/100 | Batch 200/600 | Cost: 0.0515
# Epoch 024/100 | Batch 250/600 | Cost: 0.0715
# Epoch 024/100 | Batch 300/600 | Cost: 0.0862
# Epoch 024/100 | Batch 350/600 | Cost: 0.0131
# Epoch 024/100 | Batch 400/600 | Cost: 0.0358
# Epoch 024/100 | Batch 450/600 | Cost: 0.0344
# Epoch 024/100 | Batch 500/600 | Cost: 0.0385
# Epoch 024/100 | Batch 550/600 | Cost: 0.1495
# Epoch 024/100 | Cost: 0.0364
# Time: 6.35 min
# Epoch 025/100 | Batch 000/600 | Cost: 0.0147
# Epoch 025/100 | Batch 050/600 | Cost: 0.0284
# Epoch 025/100 | Batch 100/600 | Cost: 0.0106
# Epoch 025/100 | Batch 150/600 | Cost: 0.0376
# Epoch 025/100 | Batch 200/600 | Cost: 0.0189
# Epoch 025/100 | Batch 250/600 | Cost: 0.0423
# Epoch 025/100 | Batch 300/600 | Cost: 0.0580
# Epoch 025/100 | Batch 350/600 | Cost: 0.0661
# Epoch 025/100 | Batch 400/600 | Cost: 0.0188
# Epoch 025/100 | Batch 450/600 | Cost: 0.0116
# Epoch 025/100 | Batch 500/600 | Cost: 0.0361
# Epoch 025/100 | Batch 550/600 | Cost: 0.0844
# Epoch 025/100 | Cost: 0.0345
# Time: 6.62 min
# Epoch 026/100 | Batch 000/600 | Cost: 0.0188
# Epoch 026/100 | Batch 050/600 | Cost: 0.0437
# Epoch 026/100 | Batch 100/600 | Cost: 0.0367
# Epoch 026/100 | Batch 150/600 | Cost: 0.0298
# Epoch 026/100 | Batch 200/600 | Cost: 0.0365
# Epoch 026/100 | Batch 250/600 | Cost: 0.0278
# Epoch 026/100 | Batch 300/600 | Cost: 0.0431
# Epoch 026/100 | Batch 350/600 | Cost: 0.0298
# Epoch 026/100 | Batch 400/600 | Cost: 0.0340
# Epoch 026/100 | Batch 450/600 | Cost: 0.0200
# Epoch 026/100 | Batch 500/600 | Cost: 0.0468
# Epoch 026/100 | Batch 550/600 | Cost: 0.0348
# Epoch 026/100 | Cost: 0.0329
# Time: 6.87 min
# Epoch 027/100 | Batch 000/600 | Cost: 0.0904
# Epoch 027/100 | Batch 050/600 | Cost: 0.0186
# Epoch 027/100 | Batch 100/600 | Cost: 0.0284
# Epoch 027/100 | Batch 150/600 | Cost: 0.0340
# Epoch 027/100 | Batch 200/600 | Cost: 0.0240
# Epoch 027/100 | Batch 250/600 | Cost: 0.0320
# Epoch 027/100 | Batch 300/600 | Cost: 0.0297
# Epoch 027/100 | Batch 350/600 | Cost: 0.0531
# Epoch 027/100 | Batch 400/600 | Cost: 0.0337
# Epoch 027/100 | Batch 450/600 | Cost: 0.0226
# Epoch 027/100 | Batch 500/600 | Cost: 0.0206
# Epoch 027/100 | Batch 550/600 | Cost: 0.0234
# Epoch 027/100 | Cost: 0.0336
# Time: 7.14 min
# Epoch 028/100 | Batch 000/600 | Cost: 0.0508
# Epoch 028/100 | Batch 050/600 | Cost: 0.1016
# Epoch 028/100 | Batch 100/600 | Cost: 0.0261
# Epoch 028/100 | Batch 150/600 | Cost: 0.0187
# Epoch 028/100 | Batch 200/600 | Cost: 0.0542
# Epoch 028/100 | Batch 250/600 | Cost: 0.0456
# Epoch 028/100 | Batch 300/600 | Cost: 0.0229
# Epoch 028/100 | Batch 350/600 | Cost: 0.0138
# Epoch 028/100 | Batch 400/600 | Cost: 0.0217
# Epoch 028/100 | Batch 450/600 | Cost: 0.0212
# Epoch 028/100 | Batch 500/600 | Cost: 0.0233
# Epoch 028/100 | Batch 550/600 | Cost: 0.0153
# Epoch 028/100 | Cost: 0.0303
# Time: 7.40 min
# Epoch 029/100 | Batch 000/600 | Cost: 0.0506
# Epoch 029/100 | Batch 050/600 | Cost: 0.0315
# Epoch 029/100 | Batch 100/600 | Cost: 0.0203
# Epoch 029/100 | Batch 150/600 | Cost: 0.0272
# Epoch 029/100 | Batch 200/600 | Cost: 0.0208
# Epoch 029/100 | Batch 250/600 | Cost: 0.0449
# Epoch 029/100 | Batch 300/600 | Cost: 0.0678
# Epoch 029/100 | Batch 350/600 | Cost: 0.0222
# Epoch 029/100 | Batch 400/600 | Cost: 0.0144
# Epoch 029/100 | Batch 450/600 | Cost: 0.0163
# Epoch 029/100 | Batch 500/600 | Cost: 0.0750
# Epoch 029/100 | Batch 550/600 | Cost: 0.0120
# Epoch 029/100 | Cost: 0.0290
# Time: 7.67 min
# Epoch 030/100 | Batch 000/600 | Cost: 0.0353
# Epoch 030/100 | Batch 050/600 | Cost: 0.0205
# Epoch 030/100 | Batch 100/600 | Cost: 0.0250
# Epoch 030/100 | Batch 150/600 | Cost: 0.0240
# Epoch 030/100 | Batch 200/600 | Cost: 0.0229
# Epoch 030/100 | Batch 250/600 | Cost: 0.0299
# Epoch 030/100 | Batch 300/600 | Cost: 0.0460
# Epoch 030/100 | Batch 350/600 | Cost: 0.0170
# Epoch 030/100 | Batch 400/600 | Cost: 0.0307
# Epoch 030/100 | Batch 450/600 | Cost: 0.0139
# Epoch 030/100 | Batch 500/600 | Cost: 0.0194
# Epoch 030/100 | Batch 550/600 | Cost: 0.0192
# Epoch 030/100 | Cost: 0.0273
# Time: 7.92 min
# Epoch 031/100 | Batch 000/600 | Cost: 0.0130
# Epoch 031/100 | Batch 050/600 | Cost: 0.0460
# Epoch 031/100 | Batch 100/600 | Cost: 0.0334
# Epoch 031/100 | Batch 150/600 | Cost: 0.0428
# Epoch 031/100 | Batch 200/600 | Cost: 0.0372
# Epoch 031/100 | Batch 250/600 | Cost: 0.0215
# Epoch 031/100 | Batch 300/600 | Cost: 0.0236
# Epoch 031/100 | Batch 350/600 | Cost: 0.0243
# Epoch 031/100 | Batch 400/600 | Cost: 0.0186
# Epoch 031/100 | Batch 450/600 | Cost: 0.0312
# Epoch 031/100 | Batch 500/600 | Cost: 0.0346
# Epoch 031/100 | Batch 550/600 | Cost: 0.0226
# Epoch 031/100 | Cost: 0.0260
# Time: 8.19 min
# Epoch 032/100 | Batch 000/600 | Cost: 0.0067
# Epoch 032/100 | Batch 050/600 | Cost: 0.0157
# Epoch 032/100 | Batch 100/600 | Cost: 0.0088
# Epoch 032/100 | Batch 150/600 | Cost: 0.0129
# Epoch 032/100 | Batch 200/600 | Cost: 0.0316
# Epoch 032/100 | Batch 250/600 | Cost: 0.0134
# Epoch 032/100 | Batch 300/600 | Cost: 0.0111
# Epoch 032/100 | Batch 350/600 | Cost: 0.0320
# Epoch 032/100 | Batch 400/600 | Cost: 0.0322
# Epoch 032/100 | Batch 450/600 | Cost: 0.0158
# Epoch 032/100 | Batch 500/600 | Cost: 0.0122
# Epoch 032/100 | Batch 550/600 | Cost: 0.0067
# Epoch 032/100 | Cost: 0.0245
# Time: 8.45 min
# Epoch 033/100 | Batch 000/600 | Cost: 0.0083
# Epoch 033/100 | Batch 050/600 | Cost: 0.0063
# Epoch 033/100 | Batch 100/600 | Cost: 0.0226
# Epoch 033/100 | Batch 150/600 | Cost: 0.0345
# Epoch 033/100 | Batch 200/600 | Cost: 0.0207
# Epoch 033/100 | Batch 250/600 | Cost: 0.0196
# Epoch 033/100 | Batch 300/600 | Cost: 0.0098
# Epoch 033/100 | Batch 350/600 | Cost: 0.0162
# Epoch 033/100 | Batch 400/600 | Cost: 0.0325
# Epoch 033/100 | Batch 450/600 | Cost: 0.0263
# Epoch 033/100 | Batch 500/600 | Cost: 0.0139
# Epoch 033/100 | Batch 550/600 | Cost: 0.0739
# Epoch 033/100 | Cost: 0.0250
# Time: 8.71 min
# Epoch 034/100 | Batch 000/600 | Cost: 0.0359
# Epoch 034/100 | Batch 050/600 | Cost: 0.0164
# Epoch 034/100 | Batch 100/600 | Cost: 0.0317
# Epoch 034/100 | Batch 150/600 | Cost: 0.0141
# Epoch 034/100 | Batch 200/600 | Cost: 0.0133
# Epoch 034/100 | Batch 250/600 | Cost: 0.0238
# Epoch 034/100 | Batch 300/600 | Cost: 0.0766
# Epoch 034/100 | Batch 350/600 | Cost: 0.0322
# Epoch 034/100 | Batch 400/600 | Cost: 0.0339
# Epoch 034/100 | Batch 450/600 | Cost: 0.0247
# Epoch 034/100 | Batch 500/600 | Cost: 0.0113
# Epoch 034/100 | Batch 550/600 | Cost: 0.0221
# Epoch 034/100 | Cost: 0.0227
# Time: 8.97 min
# Epoch 035/100 | Batch 000/600 | Cost: 0.0214
# Epoch 035/100 | Batch 050/600 | Cost: 0.0172
# Epoch 035/100 | Batch 100/600 | Cost: 0.0182
# Epoch 035/100 | Batch 150/600 | Cost: 0.0249
# Epoch 035/100 | Batch 200/600 | Cost: 0.0054
# Epoch 035/100 | Batch 250/600 | Cost: 0.0168
# Epoch 035/100 | Batch 300/600 | Cost: 0.0087
# Epoch 035/100 | Batch 350/600 | Cost: 0.0242
# Epoch 035/100 | Batch 400/600 | Cost: 0.0291
# Epoch 035/100 | Batch 450/600 | Cost: 0.0233
# Epoch 035/100 | Batch 500/600 | Cost: 0.0244
# Epoch 035/100 | Batch 550/600 | Cost: 0.0103
# Epoch 035/100 | Cost: 0.0214
# Time: 9.24 min
# Epoch 036/100 | Batch 000/600 | Cost: 0.0222
# Epoch 036/100 | Batch 050/600 | Cost: 0.0084
# Epoch 036/100 | Batch 100/600 | Cost: 0.0257
# Epoch 036/100 | Batch 150/600 | Cost: 0.0220
# Epoch 036/100 | Batch 200/600 | Cost: 0.0395
# Epoch 036/100 | Batch 250/600 | Cost: 0.0072
# Epoch 036/100 | Batch 300/600 | Cost: 0.0207
# Epoch 036/100 | Batch 350/600 | Cost: 0.0140
# Epoch 036/100 | Batch 400/600 | Cost: 0.0219
# Epoch 036/100 | Batch 450/600 | Cost: 0.0115
# Epoch 036/100 | Batch 500/600 | Cost: 0.0242
# Epoch 036/100 | Batch 550/600 | Cost: 0.0096
# Epoch 036/100 | Cost: 0.0214
# Time: 9.49 min
# Epoch 037/100 | Batch 000/600 | Cost: 0.0071
# Epoch 037/100 | Batch 050/600 | Cost: 0.0047
# Epoch 037/100 | Batch 100/600 | Cost: 0.0466
# Epoch 037/100 | Batch 150/600 | Cost: 0.0206
# Epoch 037/100 | Batch 200/600 | Cost: 0.0473
# Epoch 037/100 | Batch 250/600 | Cost: 0.0112
# Epoch 037/100 | Batch 300/600 | Cost: 0.0110
# Epoch 037/100 | Batch 350/600 | Cost: 0.0326
# Epoch 037/100 | Batch 400/600 | Cost: 0.0176
# Epoch 037/100 | Batch 450/600 | Cost: 0.0098
# Epoch 037/100 | Batch 500/600 | Cost: 0.1306
# Epoch 037/100 | Batch 550/600 | Cost: 0.0082
# Epoch 037/100 | Cost: 0.0200
# Time: 9.75 min
# Epoch 038/100 | Batch 000/600 | Cost: 0.0170
# Epoch 038/100 | Batch 050/600 | Cost: 0.0224
# Epoch 038/100 | Batch 100/600 | Cost: 0.0074
# Epoch 038/100 | Batch 150/600 | Cost: 0.0237
# Epoch 038/100 | Batch 200/600 | Cost: 0.0142
# Epoch 038/100 | Batch 250/600 | Cost: 0.0125
# Epoch 038/100 | Batch 300/600 | Cost: 0.0162
# Epoch 038/100 | Batch 350/600 | Cost: 0.0061
# Epoch 038/100 | Batch 400/600 | Cost: 0.0228
# Epoch 038/100 | Batch 450/600 | Cost: 0.0157
# Epoch 038/100 | Batch 500/600 | Cost: 0.0160
# Epoch 038/100 | Batch 550/600 | Cost: 0.0117
# Epoch 038/100 | Cost: 0.0187
# Time: 10.01 min
# Epoch 039/100 | Batch 000/600 | Cost: 0.0124
# Epoch 039/100 | Batch 050/600 | Cost: 0.0036
# Epoch 039/100 | Batch 100/600 | Cost: 0.0106
# Epoch 039/100 | Batch 150/600 | Cost: 0.0156
# Epoch 039/100 | Batch 200/600 | Cost: 0.0136
# Epoch 039/100 | Batch 250/600 | Cost: 0.0143
# Epoch 039/100 | Batch 300/600 | Cost: 0.0246
# Epoch 039/100 | Batch 350/600 | Cost: 0.0150
# Epoch 039/100 | Batch 400/600 | Cost: 0.0103
# Epoch 039/100 | Batch 450/600 | Cost: 0.0131
# Epoch 039/100 | Batch 500/600 | Cost: 0.0247
# Epoch 039/100 | Batch 550/600 | Cost: 0.0181
# Epoch 039/100 | Cost: 0.0180
# Time: 10.28 min
# Epoch 040/100 | Batch 000/600 | Cost: 0.0064
# Epoch 040/100 | Batch 050/600 | Cost: 0.0112
# Epoch 040/100 | Batch 100/600 | Cost: 0.0059
# Epoch 040/100 | Batch 150/600 | Cost: 0.0069
# Epoch 040/100 | Batch 200/600 | Cost: 0.0176
# Epoch 040/100 | Batch 250/600 | Cost: 0.0167
# Epoch 040/100 | Batch 300/600 | Cost: 0.0121
# Epoch 040/100 | Batch 350/600 | Cost: 0.0082
# Epoch 040/100 | Batch 400/600 | Cost: 0.1588
# Epoch 040/100 | Batch 450/600 | Cost: 0.0087
# Epoch 040/100 | Batch 500/600 | Cost: 0.0504
# Epoch 040/100 | Batch 550/600 | Cost: 0.0097
# Epoch 040/100 | Cost: 0.0175
# Time: 10.54 min
# Epoch 041/100 | Batch 000/600 | Cost: 0.0187
# Epoch 041/100 | Batch 050/600 | Cost: 0.0198
# Epoch 041/100 | Batch 100/600 | Cost: 0.0111
# Epoch 041/100 | Batch 150/600 | Cost: 0.0209
# Epoch 041/100 | Batch 200/600 | Cost: 0.0088
# Epoch 041/100 | Batch 250/600 | Cost: 0.0103
# Epoch 041/100 | Batch 300/600 | Cost: 0.0114
# Epoch 041/100 | Batch 350/600 | Cost: 0.0192
# Epoch 041/100 | Batch 400/600 | Cost: 0.0152
# Epoch 041/100 | Batch 450/600 | Cost: 0.0239
# Epoch 041/100 | Batch 500/600 | Cost: 0.0112
# Epoch 041/100 | Batch 550/600 | Cost: 0.0073
# Epoch 041/100 | Cost: 0.0165
# Time: 10.80 min
# Epoch 042/100 | Batch 000/600 | Cost: 0.0319
# Epoch 042/100 | Batch 050/600 | Cost: 0.0122
# Epoch 042/100 | Batch 100/600 | Cost: 0.0093
# Epoch 042/100 | Batch 150/600 | Cost: 0.0035
# Epoch 042/100 | Batch 200/600 | Cost: 0.0108
# Epoch 042/100 | Batch 250/600 | Cost: 0.0464
# Epoch 042/100 | Batch 300/600 | Cost: 0.0143
# Epoch 042/100 | Batch 350/600 | Cost: 0.0092
# Epoch 042/100 | Batch 400/600 | Cost: 0.0204
# Epoch 042/100 | Batch 450/600 | Cost: 0.0110
# Epoch 042/100 | Batch 500/600 | Cost: 0.0150
# Epoch 042/100 | Batch 550/600 | Cost: 0.0092
# Epoch 042/100 | Cost: 0.0165
# Time: 11.06 min
# Epoch 043/100 | Batch 000/600 | Cost: 0.0146
# Epoch 043/100 | Batch 050/600 | Cost: 0.0286
# Epoch 043/100 | Batch 100/600 | Cost: 0.0157
# Epoch 043/100 | Batch 150/600 | Cost: 0.0194
# Epoch 043/100 | Batch 200/600 | Cost: 0.0040
# Epoch 043/100 | Batch 250/600 | Cost: 0.0182
# Epoch 043/100 | Batch 300/600 | Cost: 0.0342
# Epoch 043/100 | Batch 350/600 | Cost: 0.0195
# Epoch 043/100 | Batch 400/600 | Cost: 0.0262
# Epoch 043/100 | Batch 450/600 | Cost: 0.0274
# Epoch 043/100 | Batch 500/600 | Cost: 0.0161
# Epoch 043/100 | Batch 550/600 | Cost: 0.0113
# Epoch 043/100 | Cost: 0.0154
# Time: 11.32 min
# Epoch 044/100 | Batch 000/600 | Cost: 0.0134
# Epoch 044/100 | Batch 050/600 | Cost: 0.0183
# Epoch 044/100 | Batch 100/600 | Cost: 0.0070
# Epoch 044/100 | Batch 150/600 | Cost: 0.0036
# Epoch 044/100 | Batch 200/600 | Cost: 0.0077
# Epoch 044/100 | Batch 250/600 | Cost: 0.0073
# Epoch 044/100 | Batch 300/600 | Cost: 0.0171
# Epoch 044/100 | Batch 350/600 | Cost: 0.0094
# Epoch 044/100 | Batch 400/600 | Cost: 0.0061
# Epoch 044/100 | Batch 450/600 | Cost: 0.0072
# Epoch 044/100 | Batch 500/600 | Cost: 0.0122
# Epoch 044/100 | Batch 550/600 | Cost: 0.0215
# Epoch 044/100 | Cost: 0.0148
# Time: 11.58 min
# Epoch 045/100 | Batch 000/600 | Cost: 0.0058
# Epoch 045/100 | Batch 050/600 | Cost: 0.0121
# Epoch 045/100 | Batch 100/600 | Cost: 0.0578
# Epoch 045/100 | Batch 150/600 | Cost: 0.0041
# Epoch 045/100 | Batch 200/600 | Cost: 0.0086
# Epoch 045/100 | Batch 250/600 | Cost: 0.0534
# Epoch 045/100 | Batch 300/600 | Cost: 0.0191
# Epoch 045/100 | Batch 350/600 | Cost: 0.0252
# Epoch 045/100 | Batch 400/600 | Cost: 0.0162
# Epoch 045/100 | Batch 450/600 | Cost: 0.0114
# Epoch 045/100 | Batch 500/600 | Cost: 0.0047
# Epoch 045/100 | Batch 550/600 | Cost: 0.0067
# Epoch 045/100 | Cost: 0.0145
# Time: 11.85 min
# Epoch 046/100 | Batch 000/600 | Cost: 0.0064
# Epoch 046/100 | Batch 050/600 | Cost: 0.0083
# Epoch 046/100 | Batch 100/600 | Cost: 0.0081
# Epoch 046/100 | Batch 150/600 | Cost: 0.0132
# Epoch 046/100 | Batch 200/600 | Cost: 0.0244
# Epoch 046/100 | Batch 250/600 | Cost: 0.0081
# Epoch 046/100 | Batch 300/600 | Cost: 0.0113
# Epoch 046/100 | Batch 350/600 | Cost: 0.0150
# Epoch 046/100 | Batch 400/600 | Cost: 0.0085
# Epoch 046/100 | Batch 450/600 | Cost: 0.0075
# Epoch 046/100 | Batch 500/600 | Cost: 0.0036
# Epoch 046/100 | Batch 550/600 | Cost: 0.0045
# Epoch 046/100 | Cost: 0.0142
# Time: 12.12 min
# Epoch 047/100 | Batch 000/600 | Cost: 0.0219
# Epoch 047/100 | Batch 050/600 | Cost: 0.0152
# Epoch 047/100 | Batch 100/600 | Cost: 0.0127
# Epoch 047/100 | Batch 150/600 | Cost: 0.0207
# Epoch 047/100 | Batch 200/600 | Cost: 0.0235
# Epoch 047/100 | Batch 250/600 | Cost: 0.0588
# Epoch 047/100 | Batch 300/600 | Cost: 0.0097
# Epoch 047/100 | Batch 350/600 | Cost: 0.0141
# Epoch 047/100 | Batch 400/600 | Cost: 0.0086
# Epoch 047/100 | Batch 450/600 | Cost: 0.0266
# Epoch 047/100 | Batch 500/600 | Cost: 0.0148
# Epoch 047/100 | Batch 550/600 | Cost: 0.0086
# Epoch 047/100 | Cost: 0.0131
# Time: 12.38 min
# Epoch 048/100 | Batch 000/600 | Cost: 0.0219
# Epoch 048/100 | Batch 050/600 | Cost: 0.0053
# Epoch 048/100 | Batch 100/600 | Cost: 0.0202
# Epoch 048/100 | Batch 150/600 | Cost: 0.0083
# Epoch 048/100 | Batch 200/600 | Cost: 0.0147
# Epoch 048/100 | Batch 250/600 | Cost: 0.0081
# Epoch 048/100 | Batch 300/600 | Cost: 0.0196
# Epoch 048/100 | Batch 350/600 | Cost: 0.0101
# Epoch 048/100 | Batch 400/600 | Cost: 0.0157
# Epoch 048/100 | Batch 450/600 | Cost: 0.0405
# Epoch 048/100 | Batch 500/600 | Cost: 0.0103
# Epoch 048/100 | Batch 550/600 | Cost: 0.0117
# Epoch 048/100 | Cost: 0.0133
# Time: 12.64 min
# Epoch 049/100 | Batch 000/600 | Cost: 0.0083
# Epoch 049/100 | Batch 050/600 | Cost: 0.0119
# Epoch 049/100 | Batch 100/600 | Cost: 0.0940
# Epoch 049/100 | Batch 150/600 | Cost: 0.0062
# Epoch 049/100 | Batch 200/600 | Cost: 0.0134
# Epoch 049/100 | Batch 250/600 | Cost: 0.0066
# Epoch 049/100 | Batch 300/600 | Cost: 0.0077
# Epoch 049/100 | Batch 350/600 | Cost: 0.0121
# Epoch 049/100 | Batch 400/600 | Cost: 0.0278
# Epoch 049/100 | Batch 450/600 | Cost: 0.0144
# Epoch 049/100 | Batch 500/600 | Cost: 0.0158
# Epoch 049/100 | Batch 550/600 | Cost: 0.0141
# Epoch 049/100 | Cost: 0.0125
# Time: 12.92 min
# Epoch 050/100 | Batch 000/600 | Cost: 0.0154
# Epoch 050/100 | Batch 050/600 | Cost: 0.0109
# Epoch 050/100 | Batch 100/600 | Cost: 0.0050
# Epoch 050/100 | Batch 150/600 | Cost: 0.0126
# Epoch 050/100 | Batch 200/600 | Cost: 0.0207
# Epoch 050/100 | Batch 250/600 | Cost: 0.0234
# Epoch 050/100 | Batch 300/600 | Cost: 0.0094
# Epoch 050/100 | Batch 350/600 | Cost: 0.0071
# Epoch 050/100 | Batch 400/600 | Cost: 0.0109
# Epoch 050/100 | Batch 450/600 | Cost: 0.0053
# Epoch 050/100 | Batch 500/600 | Cost: 0.0045
# Epoch 050/100 | Batch 550/600 | Cost: 0.0066
# Epoch 050/100 | Cost: 0.0118
# Time: 13.18 min
# Epoch 051/100 | Batch 000/600 | Cost: 0.0050
# Epoch 051/100 | Batch 050/600 | Cost: 0.0036
# Epoch 051/100 | Batch 100/600 | Cost: 0.0107
# Epoch 051/100 | Batch 150/600 | Cost: 0.0061
# Epoch 051/100 | Batch 200/600 | Cost: 0.0063
# Epoch 051/100 | Batch 250/600 | Cost: 0.0083
# Epoch 051/100 | Batch 300/600 | Cost: 0.0273
# Epoch 051/100 | Batch 350/600 | Cost: 0.0178
# Epoch 051/100 | Batch 400/600 | Cost: 0.0109
# Epoch 051/100 | Batch 450/600 | Cost: 0.0128
# Epoch 051/100 | Batch 500/600 | Cost: 0.0085
# Epoch 051/100 | Batch 550/600 | Cost: 0.0446
# Epoch 051/100 | Cost: 0.0116
# Time: 13.45 min
# Epoch 052/100 | Batch 000/600 | Cost: 0.0127
# Epoch 052/100 | Batch 050/600 | Cost: 0.0074
# Epoch 052/100 | Batch 100/600 | Cost: 0.0138
# Epoch 052/100 | Batch 150/600 | Cost: 0.0169
# Epoch 052/100 | Batch 200/600 | Cost: 0.0103
# Epoch 052/100 | Batch 250/600 | Cost: 0.0143
# Epoch 052/100 | Batch 300/600 | Cost: 0.0099
# Epoch 052/100 | Batch 350/600 | Cost: 0.0090
# Epoch 052/100 | Batch 400/600 | Cost: 0.0144
# Epoch 052/100 | Batch 450/600 | Cost: 0.0657
# Epoch 052/100 | Batch 500/600 | Cost: 0.0281
# Epoch 052/100 | Batch 550/600 | Cost: 0.0061
# Epoch 052/100 | Cost: 0.0112
# Time: 13.71 min
# Epoch 053/100 | Batch 000/600 | Cost: 0.0104
# Epoch 053/100 | Batch 050/600 | Cost: 0.0133
# Epoch 053/100 | Batch 100/600 | Cost: 0.0069
# Epoch 053/100 | Batch 150/600 | Cost: 0.0118
# Epoch 053/100 | Batch 200/600 | Cost: 0.0140
# Epoch 053/100 | Batch 250/600 | Cost: 0.0140
# Epoch 053/100 | Batch 300/600 | Cost: 0.0132
# Epoch 053/100 | Batch 350/600 | Cost: 0.0134
# Epoch 053/100 | Batch 400/600 | Cost: 0.0044
# Epoch 053/100 | Batch 450/600 | Cost: 0.0143
# Epoch 053/100 | Batch 500/600 | Cost: 0.0027
# Epoch 053/100 | Batch 550/600 | Cost: 0.0048
# Epoch 053/100 | Cost: 0.0107
# Time: 13.97 min
# Epoch 054/100 | Batch 000/600 | Cost: 0.0083
# Epoch 054/100 | Batch 050/600 | Cost: 0.0192
# Epoch 054/100 | Batch 100/600 | Cost: 0.0134
# Epoch 054/100 | Batch 150/600 | Cost: 0.0053
# Epoch 054/100 | Batch 200/600 | Cost: 0.0009
# Epoch 054/100 | Batch 250/600 | Cost: 0.0073
# Epoch 054/100 | Batch 300/600 | Cost: 0.0163
# Epoch 054/100 | Batch 350/600 | Cost: 0.0131
# Epoch 054/100 | Batch 400/600 | Cost: 0.0062
# Epoch 054/100 | Batch 450/600 | Cost: 0.0039
# Epoch 054/100 | Batch 500/600 | Cost: 0.0198
# Epoch 054/100 | Batch 550/600 | Cost: 0.0251
# Epoch 054/100 | Cost: 0.0103
# Time: 14.23 min
# Epoch 055/100 | Batch 000/600 | Cost: 0.0142
# Epoch 055/100 | Batch 050/600 | Cost: 0.0072
# Epoch 055/100 | Batch 100/600 | Cost: 0.0056
# Epoch 055/100 | Batch 150/600 | Cost: 0.0060
# Epoch 055/100 | Batch 200/600 | Cost: 0.0347
# Epoch 055/100 | Batch 250/600 | Cost: 0.0067
# Epoch 055/100 | Batch 300/600 | Cost: 0.0074
# Epoch 055/100 | Batch 350/600 | Cost: 0.0240
# Epoch 055/100 | Batch 400/600 | Cost: 0.0066
# Epoch 055/100 | Batch 450/600 | Cost: 0.0060
# Epoch 055/100 | Batch 500/600 | Cost: 0.0175
# Epoch 055/100 | Batch 550/600 | Cost: 0.0128
# Epoch 055/100 | Cost: 0.0105
# Time: 14.50 min
# Epoch 056/100 | Batch 000/600 | Cost: 0.0027
# Epoch 056/100 | Batch 050/600 | Cost: 0.0182
# Epoch 056/100 | Batch 100/600 | Cost: 0.0076
# Epoch 056/100 | Batch 150/600 | Cost: 0.0095
# Epoch 056/100 | Batch 200/600 | Cost: 0.0140
# Epoch 056/100 | Batch 250/600 | Cost: 0.0084
# Epoch 056/100 | Batch 300/600 | Cost: 0.0764
# Epoch 056/100 | Batch 350/600 | Cost: 0.0125
# Epoch 056/100 | Batch 400/600 | Cost: 0.0153
# Epoch 056/100 | Batch 450/600 | Cost: 0.0088
# Epoch 056/100 | Batch 500/600 | Cost: 0.0579
# Epoch 056/100 | Batch 550/600 | Cost: 0.0116
# Epoch 056/100 | Cost: 0.0103
# Time: 14.77 min
# Epoch 057/100 | Batch 000/600 | Cost: 0.0175
# Epoch 057/100 | Batch 050/600 | Cost: 0.0882
# Epoch 057/100 | Batch 100/600 | Cost: 0.0081
# Epoch 057/100 | Batch 150/600 | Cost: 0.0090
# Epoch 057/100 | Batch 200/600 | Cost: 0.0030
# Epoch 057/100 | Batch 250/600 | Cost: 0.0170
# Epoch 057/100 | Batch 300/600 | Cost: 0.0093
# Epoch 057/100 | Batch 350/600 | Cost: 0.0133
# Epoch 057/100 | Batch 400/600 | Cost: 0.0036
# Epoch 057/100 | Batch 450/600 | Cost: 0.0107
# Epoch 057/100 | Batch 500/600 | Cost: 0.0094
# Epoch 057/100 | Batch 550/600 | Cost: 0.0139
# Epoch 057/100 | Cost: 0.0095
# Time: 15.04 min
# Epoch 058/100 | Batch 000/600 | Cost: 0.0076
# Epoch 058/100 | Batch 050/600 | Cost: 0.0053
# Epoch 058/100 | Batch 100/600 | Cost: 0.0077
# Epoch 058/100 | Batch 150/600 | Cost: 0.0087
# Epoch 058/100 | Batch 200/600 | Cost: 0.0037
# Epoch 058/100 | Batch 250/600 | Cost: 0.0095
# Epoch 058/100 | Batch 300/600 | Cost: 0.0057
# Epoch 058/100 | Batch 350/600 | Cost: 0.0036
# Epoch 058/100 | Batch 400/600 | Cost: 0.0078
# Epoch 058/100 | Batch 450/600 | Cost: 0.0079
# Epoch 058/100 | Batch 500/600 | Cost: 0.0078
# Epoch 058/100 | Batch 550/600 | Cost: 0.0072
# Epoch 058/100 | Cost: 0.0100
# Time: 15.31 min
# Epoch 059/100 | Batch 000/600 | Cost: 0.0024
# Epoch 059/100 | Batch 050/600 | Cost: 0.0059
# Epoch 059/100 | Batch 100/600 | Cost: 0.0104
# Epoch 059/100 | Batch 150/600 | Cost: 0.0049
# Epoch 059/100 | Batch 200/600 | Cost: 0.0144
# Epoch 059/100 | Batch 250/600 | Cost: 0.0200
# Epoch 059/100 | Batch 300/600 | Cost: 0.0078
# Epoch 059/100 | Batch 350/600 | Cost: 0.0044
# Epoch 059/100 | Batch 400/600 | Cost: 0.0103
# Epoch 059/100 | Batch 450/600 | Cost: 0.0040
# Epoch 059/100 | Batch 500/600 | Cost: 0.0131
# Epoch 059/100 | Batch 550/600 | Cost: 0.0071
# Epoch 059/100 | Cost: 0.0092
# Time: 15.58 min
# Epoch 060/100 | Batch 000/600 | Cost: 0.0065
# Epoch 060/100 | Batch 050/600 | Cost: 0.0140
# Epoch 060/100 | Batch 100/600 | Cost: 0.0097
# Epoch 060/100 | Batch 150/600 | Cost: 0.0112
# Epoch 060/100 | Batch 200/600 | Cost: 0.0124
# Epoch 060/100 | Batch 250/600 | Cost: 0.0112
# Epoch 060/100 | Batch 300/600 | Cost: 0.0110
# Epoch 060/100 | Batch 350/600 | Cost: 0.0040
# Epoch 060/100 | Batch 400/600 | Cost: 0.0132
# Epoch 060/100 | Batch 450/600 | Cost: 0.0131
# Epoch 060/100 | Batch 500/600 | Cost: 0.0045
# Epoch 060/100 | Batch 550/600 | Cost: 0.0124
# Epoch 060/100 | Cost: 0.0086
# Time: 15.85 min
# Epoch 061/100 | Batch 000/600 | Cost: 0.0051
# Epoch 061/100 | Batch 050/600 | Cost: 0.0087
# Epoch 061/100 | Batch 100/600 | Cost: 0.0032
# Epoch 061/100 | Batch 150/600 | Cost: 0.0080
# Epoch 061/100 | Batch 200/600 | Cost: 0.0125
# Epoch 061/100 | Batch 250/600 | Cost: 0.0060
# Epoch 061/100 | Batch 300/600 | Cost: 0.0082
# Epoch 061/100 | Batch 350/600 | Cost: 0.0024
# Epoch 061/100 | Batch 400/600 | Cost: 0.0047
# Epoch 061/100 | Batch 450/600 | Cost: 0.0098
# Epoch 061/100 | Batch 500/600 | Cost: 0.0095
# Epoch 061/100 | Batch 550/600 | Cost: 0.0039
# Epoch 061/100 | Cost: 0.0086
# Time: 16.12 min
# Epoch 062/100 | Batch 000/600 | Cost: 0.0055
# Epoch 062/100 | Batch 050/600 | Cost: 0.0146
# Epoch 062/100 | Batch 100/600 | Cost: 0.0850
# Epoch 062/100 | Batch 150/600 | Cost: 0.0121
# Epoch 062/100 | Batch 200/600 | Cost: 0.0123
# Epoch 062/100 | Batch 250/600 | Cost: 0.0179
# Epoch 062/100 | Batch 300/600 | Cost: 0.0068
# Epoch 062/100 | Batch 350/600 | Cost: 0.0076
# Epoch 062/100 | Batch 400/600 | Cost: 0.0123
# Epoch 062/100 | Batch 450/600 | Cost: 0.0036
# Epoch 062/100 | Batch 500/600 | Cost: 0.0068
# Epoch 062/100 | Batch 550/600 | Cost: 0.0023
# Epoch 062/100 | Cost: 0.0083
# Time: 16.38 min
# Epoch 063/100 | Batch 000/600 | Cost: 0.0063
# Epoch 063/100 | Batch 050/600 | Cost: 0.0038
# Epoch 063/100 | Batch 100/600 | Cost: 0.0026
# Epoch 063/100 | Batch 150/600 | Cost: 0.0021
# Epoch 063/100 | Batch 200/600 | Cost: 0.0100
# Epoch 063/100 | Batch 250/600 | Cost: 0.0079
# Epoch 063/100 | Batch 300/600 | Cost: 0.0072
# Epoch 063/100 | Batch 350/600 | Cost: 0.0100
# Epoch 063/100 | Batch 400/600 | Cost: 0.0147
# Epoch 063/100 | Batch 450/600 | Cost: 0.0032
# Epoch 063/100 | Batch 500/600 | Cost: 0.0126
# Epoch 063/100 | Batch 550/600 | Cost: 0.0048
# Epoch 063/100 | Cost: 0.0081
# Time: 16.66 min
# Epoch 064/100 | Batch 000/600 | Cost: 0.0218
# Epoch 064/100 | Batch 050/600 | Cost: 0.0090
# Epoch 064/100 | Batch 100/600 | Cost: 0.0043
# Epoch 064/100 | Batch 150/600 | Cost: 0.0068
# Epoch 064/100 | Batch 200/600 | Cost: 0.0027
# Epoch 064/100 | Batch 250/600 | Cost: 0.0022
# Epoch 064/100 | Batch 300/600 | Cost: 0.0181
# Epoch 064/100 | Batch 350/600 | Cost: 0.0160
# Epoch 064/100 | Batch 400/600 | Cost: 0.0079
# Epoch 064/100 | Batch 450/600 | Cost: 0.0046
# Epoch 064/100 | Batch 500/600 | Cost: 0.0082
# Epoch 064/100 | Batch 550/600 | Cost: 0.0074
# Epoch 064/100 | Cost: 0.0077
# Time: 16.92 min
# Epoch 065/100 | Batch 000/600 | Cost: 0.0044
# Epoch 065/100 | Batch 050/600 | Cost: 0.0017
# Epoch 065/100 | Batch 100/600 | Cost: 0.0031
# Epoch 065/100 | Batch 150/600 | Cost: 0.0069
# Epoch 065/100 | Batch 200/600 | Cost: 0.0053
# Epoch 065/100 | Batch 250/600 | Cost: 0.0082
# Epoch 065/100 | Batch 300/600 | Cost: 0.0133
# Epoch 065/100 | Batch 350/600 | Cost: 0.0038
# Epoch 065/100 | Batch 400/600 | Cost: 0.0127
# Epoch 065/100 | Batch 450/600 | Cost: 0.0031
# Epoch 065/100 | Batch 500/600 | Cost: 0.0092
# Epoch 065/100 | Batch 550/600 | Cost: 0.0049
# Epoch 065/100 | Cost: 0.0074
# Time: 17.18 min
# Epoch 066/100 | Batch 000/600 | Cost: 0.0050
# Epoch 066/100 | Batch 050/600 | Cost: 0.0049
# Epoch 066/100 | Batch 100/600 | Cost: 0.0061
# Epoch 066/100 | Batch 150/600 | Cost: 0.0071
# Epoch 066/100 | Batch 200/600 | Cost: 0.0071
# Epoch 066/100 | Batch 250/600 | Cost: 0.0084
# Epoch 066/100 | Batch 300/600 | Cost: 0.0118
# Epoch 066/100 | Batch 350/600 | Cost: 0.0161
# Epoch 066/100 | Batch 400/600 | Cost: 0.0071
# Epoch 066/100 | Batch 450/600 | Cost: 0.0059
# Epoch 066/100 | Batch 500/600 | Cost: 0.0063
# Epoch 066/100 | Batch 550/600 | Cost: 0.0043
# Epoch 066/100 | Cost: 0.0074
# Time: 17.45 min
# Epoch 067/100 | Batch 000/600 | Cost: 0.0055
# Epoch 067/100 | Batch 050/600 | Cost: 0.0051
# Epoch 067/100 | Batch 100/600 | Cost: 0.0034
# Epoch 067/100 | Batch 150/600 | Cost: 0.0053
# Epoch 067/100 | Batch 200/600 | Cost: 0.0051
# Epoch 067/100 | Batch 250/600 | Cost: 0.0089
# Epoch 067/100 | Batch 300/600 | Cost: 0.0064
# Epoch 067/100 | Batch 350/600 | Cost: 0.0072
# Epoch 067/100 | Batch 400/600 | Cost: 0.0116
# Epoch 067/100 | Batch 450/600 | Cost: 0.0091
# Epoch 067/100 | Batch 500/600 | Cost: 0.0146
# Epoch 067/100 | Batch 550/600 | Cost: 0.0032
# Epoch 067/100 | Cost: 0.0071
# Time: 17.71 min
# Epoch 068/100 | Batch 000/600 | Cost: 0.0181
# Epoch 068/100 | Batch 050/600 | Cost: 0.0063
# Epoch 068/100 | Batch 100/600 | Cost: 0.0084
# Epoch 068/100 | Batch 150/600 | Cost: 0.0043
# Epoch 068/100 | Batch 200/600 | Cost: 0.0028
# Epoch 068/100 | Batch 250/600 | Cost: 0.0141
# Epoch 068/100 | Batch 300/600 | Cost: 0.0051
# Epoch 068/100 | Batch 350/600 | Cost: 0.0048
# Epoch 068/100 | Batch 400/600 | Cost: 0.0054
# Epoch 068/100 | Batch 450/600 | Cost: 0.0042
# Epoch 068/100 | Batch 500/600 | Cost: 0.0010
# Epoch 068/100 | Batch 550/600 | Cost: 0.0114
# Epoch 068/100 | Cost: 0.0071
# Time: 17.98 min
# Epoch 069/100 | Batch 000/600 | Cost: 0.0081
# Epoch 069/100 | Batch 050/600 | Cost: 0.0168
# Epoch 069/100 | Batch 100/600 | Cost: 0.0046
# Epoch 069/100 | Batch 150/600 | Cost: 0.0096
# Epoch 069/100 | Batch 200/600 | Cost: 0.0058
# Epoch 069/100 | Batch 250/600 | Cost: 0.0024
# Epoch 069/100 | Batch 300/600 | Cost: 0.0080
# Epoch 069/100 | Batch 350/600 | Cost: 0.0102
# Epoch 069/100 | Batch 400/600 | Cost: 0.0056
# Epoch 069/100 | Batch 450/600 | Cost: 0.0034
# Epoch 069/100 | Batch 500/600 | Cost: 0.0114
# Epoch 069/100 | Batch 550/600 | Cost: 0.0061
# Epoch 069/100 | Cost: 0.0069
# Time: 18.25 min
# Epoch 070/100 | Batch 000/600 | Cost: 0.0058
# Epoch 070/100 | Batch 050/600 | Cost: 0.0034
# Epoch 070/100 | Batch 100/600 | Cost: 0.0071
# Epoch 070/100 | Batch 150/600 | Cost: 0.0080
# Epoch 070/100 | Batch 200/600 | Cost: 0.0032
# Epoch 070/100 | Batch 250/600 | Cost: 0.0038
# Epoch 070/100 | Batch 300/600 | Cost: 0.0116
# Epoch 070/100 | Batch 350/600 | Cost: 0.0073
# Epoch 070/100 | Batch 400/600 | Cost: 0.0098
# Epoch 070/100 | Batch 450/600 | Cost: 0.0070
# Epoch 070/100 | Batch 500/600 | Cost: 0.0054
# Epoch 070/100 | Batch 550/600 | Cost: 0.0040
# Epoch 070/100 | Cost: 0.0065
# Time: 18.52 min
# Epoch 071/100 | Batch 000/600 | Cost: 0.0019
# Epoch 071/100 | Batch 050/600 | Cost: 0.0113
# Epoch 071/100 | Batch 100/600 | Cost: 0.0068
# Epoch 071/100 | Batch 150/600 | Cost: 0.0053
# Epoch 071/100 | Batch 200/600 | Cost: 0.0053
# Epoch 071/100 | Batch 250/600 | Cost: 0.0041
# Epoch 071/100 | Batch 300/600 | Cost: 0.0058
# Epoch 071/100 | Batch 350/600 | Cost: 0.0048
# Epoch 071/100 | Batch 400/600 | Cost: 0.0046
# Epoch 071/100 | Batch 450/600 | Cost: 0.0023
# Epoch 071/100 | Batch 500/600 | Cost: 0.0043
# Epoch 071/100 | Batch 550/600 | Cost: 0.0047
# Epoch 071/100 | Cost: 0.0064
# Time: 18.79 min
# Epoch 072/100 | Batch 000/600 | Cost: 0.0054
# Epoch 072/100 | Batch 050/600 | Cost: 0.0100
# Epoch 072/100 | Batch 100/600 | Cost: 0.0050
# Epoch 072/100 | Batch 150/600 | Cost: 0.0019
# Epoch 072/100 | Batch 200/600 | Cost: 0.0098
# Epoch 072/100 | Batch 250/600 | Cost: 0.0069
# Epoch 072/100 | Batch 300/600 | Cost: 0.0058
# Epoch 072/100 | Batch 350/600 | Cost: 0.0036
# Epoch 072/100 | Batch 400/600 | Cost: 0.0045
# Epoch 072/100 | Batch 450/600 | Cost: 0.0114
# Epoch 072/100 | Batch 500/600 | Cost: 0.0033
# Epoch 072/100 | Batch 550/600 | Cost: 0.0022
# Epoch 072/100 | Cost: 0.0066
# Time: 19.06 min
# Epoch 073/100 | Batch 000/600 | Cost: 0.0072
# Epoch 073/100 | Batch 050/600 | Cost: 0.0040
# Epoch 073/100 | Batch 100/600 | Cost: 0.0027
# Epoch 073/100 | Batch 150/600 | Cost: 0.0020
# Epoch 073/100 | Batch 200/600 | Cost: 0.0048
# Epoch 073/100 | Batch 250/600 | Cost: 0.0160
# Epoch 073/100 | Batch 300/600 | Cost: 0.0163
# Epoch 073/100 | Batch 350/600 | Cost: 0.0171
# Epoch 073/100 | Batch 400/600 | Cost: 0.0032
# Epoch 073/100 | Batch 450/600 | Cost: 0.0038
# Epoch 073/100 | Batch 500/600 | Cost: 0.0043
# Epoch 073/100 | Batch 550/600 | Cost: 0.0010
# Epoch 073/100 | Cost: 0.0061
# Time: 19.32 min
# Epoch 074/100 | Batch 000/600 | Cost: 0.0084
# Epoch 074/100 | Batch 050/600 | Cost: 0.0041
# Epoch 074/100 | Batch 100/600 | Cost: 0.0047
# Epoch 074/100 | Batch 150/600 | Cost: 0.0060
# Epoch 074/100 | Batch 200/600 | Cost: 0.0072
# Epoch 074/100 | Batch 250/600 | Cost: 0.0056
# Epoch 074/100 | Batch 300/600 | Cost: 0.0029
# Epoch 074/100 | Batch 350/600 | Cost: 0.0051
# Epoch 074/100 | Batch 400/600 | Cost: 0.0060
# Epoch 074/100 | Batch 450/600 | Cost: 0.0034
# Epoch 074/100 | Batch 500/600 | Cost: 0.0043
# Epoch 074/100 | Batch 550/600 | Cost: 0.0067
# Epoch 074/100 | Cost: 0.0060
# Time: 19.59 min
# Epoch 075/100 | Batch 000/600 | Cost: 0.0023
# Epoch 075/100 | Batch 050/600 | Cost: 0.0034
# Epoch 075/100 | Batch 100/600 | Cost: 0.0066
# Epoch 075/100 | Batch 150/600 | Cost: 0.0024
# Epoch 075/100 | Batch 200/600 | Cost: 0.0059
# Epoch 075/100 | Batch 250/600 | Cost: 0.0052
# Epoch 075/100 | Batch 300/600 | Cost: 0.0045
# Epoch 075/100 | Batch 350/600 | Cost: 0.0029
# Epoch 075/100 | Batch 400/600 | Cost: 0.0033
# Epoch 075/100 | Batch 450/600 | Cost: 0.0060
# Epoch 075/100 | Batch 500/600 | Cost: 0.0016
# Epoch 075/100 | Batch 550/600 | Cost: 0.0042
# Epoch 075/100 | Cost: 0.0059
# Time: 19.86 min
# Epoch 076/100 | Batch 000/600 | Cost: 0.0078
# Epoch 076/100 | Batch 050/600 | Cost: 0.0086
# Epoch 076/100 | Batch 100/600 | Cost: 0.0135
# Epoch 076/100 | Batch 150/600 | Cost: 0.0032
# Epoch 076/100 | Batch 200/600 | Cost: 0.0058
# Epoch 076/100 | Batch 250/600 | Cost: 0.0029
# Epoch 076/100 | Batch 300/600 | Cost: 0.0031
# Epoch 076/100 | Batch 350/600 | Cost: 0.0060
# Epoch 076/100 | Batch 400/600 | Cost: 0.0065
# Epoch 076/100 | Batch 450/600 | Cost: 0.0042
# Epoch 076/100 | Batch 500/600 | Cost: 0.0065
# Epoch 076/100 | Batch 550/600 | Cost: 0.0046
# Epoch 076/100 | Cost: 0.0057
# Time: 20.12 min
# Epoch 077/100 | Batch 000/600 | Cost: 0.0059
# Epoch 077/100 | Batch 050/600 | Cost: 0.0038
# Epoch 077/100 | Batch 100/600 | Cost: 0.0074
# Epoch 077/100 | Batch 150/600 | Cost: 0.0014
# Epoch 077/100 | Batch 200/600 | Cost: 0.0025
# Epoch 077/100 | Batch 250/600 | Cost: 0.0027
# Epoch 077/100 | Batch 300/600 | Cost: 0.0058
# Epoch 077/100 | Batch 350/600 | Cost: 0.0050
# Epoch 077/100 | Batch 400/600 | Cost: 0.0016
# Epoch 077/100 | Batch 450/600 | Cost: 0.0028
# Epoch 077/100 | Batch 500/600 | Cost: 0.0057
# Epoch 077/100 | Batch 550/600 | Cost: 0.0111
# Epoch 077/100 | Cost: 0.0055
# Time: 20.39 min
# Epoch 078/100 | Batch 000/600 | Cost: 0.0084
# Epoch 078/100 | Batch 050/600 | Cost: 0.0065
# Epoch 078/100 | Batch 100/600 | Cost: 0.0041
# Epoch 078/100 | Batch 150/600 | Cost: 0.0052
# Epoch 078/100 | Batch 200/600 | Cost: 0.0046
# Epoch 078/100 | Batch 250/600 | Cost: 0.0057
# Epoch 078/100 | Batch 300/600 | Cost: 0.0067
# Epoch 078/100 | Batch 350/600 | Cost: 0.0074
# Epoch 078/100 | Batch 400/600 | Cost: 0.0018
# Epoch 078/100 | Batch 450/600 | Cost: 0.0011
# Epoch 078/100 | Batch 500/600 | Cost: 0.0019
# Epoch 078/100 | Batch 550/600 | Cost: 0.0141
# Epoch 078/100 | Cost: 0.0055
# Time: 20.66 min
# Epoch 079/100 | Batch 000/600 | Cost: 0.0045
# Epoch 079/100 | Batch 050/600 | Cost: 0.0034
# Epoch 079/100 | Batch 100/600 | Cost: 0.0040
# Epoch 079/100 | Batch 150/600 | Cost: 0.0020
# Epoch 079/100 | Batch 200/600 | Cost: 0.0063
# Epoch 079/100 | Batch 250/600 | Cost: 0.0029
# Epoch 079/100 | Batch 300/600 | Cost: 0.0077
# Epoch 079/100 | Batch 350/600 | Cost: 0.0064
# Epoch 079/100 | Batch 400/600 | Cost: 0.0059
# Epoch 079/100 | Batch 450/600 | Cost: 0.0076
# Epoch 079/100 | Batch 500/600 | Cost: 0.0050
# Epoch 079/100 | Batch 550/600 | Cost: 0.0086
# Epoch 079/100 | Cost: 0.0053
# Time: 20.92 min
# Epoch 080/100 | Batch 000/600 | Cost: 0.0030
# Epoch 080/100 | Batch 050/600 | Cost: 0.0083
# Epoch 080/100 | Batch 100/600 | Cost: 0.0016
# Epoch 080/100 | Batch 150/600 | Cost: 0.0025
# Epoch 080/100 | Batch 200/600 | Cost: 0.0032
# Epoch 080/100 | Batch 250/600 | Cost: 0.0027
# Epoch 080/100 | Batch 300/600 | Cost: 0.0058
# Epoch 080/100 | Batch 350/600 | Cost: 0.0049
# Epoch 080/100 | Batch 400/600 | Cost: 0.0042
# Epoch 080/100 | Batch 450/600 | Cost: 0.0116
# Epoch 080/100 | Batch 500/600 | Cost: 0.0074
# Epoch 080/100 | Batch 550/600 | Cost: 0.0044
# Epoch 080/100 | Cost: 0.0054
# Time: 21.18 min
# Epoch 081/100 | Batch 000/600 | Cost: 0.0018
# Epoch 081/100 | Batch 050/600 | Cost: 0.0025
# Epoch 081/100 | Batch 100/600 | Cost: 0.0116
# Epoch 081/100 | Batch 150/600 | Cost: 0.0035
# Epoch 081/100 | Batch 200/600 | Cost: 0.0041
# Epoch 081/100 | Batch 250/600 | Cost: 0.0068
# Epoch 081/100 | Batch 300/600 | Cost: 0.0063
# Epoch 081/100 | Batch 350/600 | Cost: 0.0053
# Epoch 081/100 | Batch 400/600 | Cost: 0.0016
# Epoch 081/100 | Batch 450/600 | Cost: 0.0020
# Epoch 081/100 | Batch 500/600 | Cost: 0.0048
# Epoch 081/100 | Batch 550/600 | Cost: 0.0033
# Epoch 081/100 | Cost: 0.0051
# Time: 21.45 min
# Epoch 082/100 | Batch 000/600 | Cost: 0.0030
# Epoch 082/100 | Batch 050/600 | Cost: 0.0029
# Epoch 082/100 | Batch 100/600 | Cost: 0.0063
# Epoch 082/100 | Batch 150/600 | Cost: 0.0031
# Epoch 082/100 | Batch 200/600 | Cost: 0.0055
# Epoch 082/100 | Batch 250/600 | Cost: 0.0035
# Epoch 082/100 | Batch 300/600 | Cost: 0.0017
# Epoch 082/100 | Batch 350/600 | Cost: 0.0061
# Epoch 082/100 | Batch 400/600 | Cost: 0.0357
# Epoch 082/100 | Batch 450/600 | Cost: 0.0124
# Epoch 082/100 | Batch 500/600 | Cost: 0.0030
# Epoch 082/100 | Batch 550/600 | Cost: 0.0024
# Epoch 082/100 | Cost: 0.0050
# Time: 21.71 min
# Epoch 083/100 | Batch 000/600 | Cost: 0.0029
# Epoch 083/100 | Batch 050/600 | Cost: 0.0030
# Epoch 083/100 | Batch 100/600 | Cost: 0.0030
# Epoch 083/100 | Batch 150/600 | Cost: 0.0042
# Epoch 083/100 | Batch 200/600 | Cost: 0.0054
# Epoch 083/100 | Batch 250/600 | Cost: 0.0066
# Epoch 083/100 | Batch 300/600 | Cost: 0.0042
# Epoch 083/100 | Batch 350/600 | Cost: 0.0024
# Epoch 083/100 | Batch 400/600 | Cost: 0.0057
# Epoch 083/100 | Batch 450/600 | Cost: 0.0029
# Epoch 083/100 | Batch 500/600 | Cost: 0.0016
# Epoch 083/100 | Batch 550/600 | Cost: 0.0042
# Epoch 083/100 | Cost: 0.0050
# Time: 21.98 min
# Epoch 084/100 | Batch 000/600 | Cost: 0.0016
# Epoch 084/100 | Batch 050/600 | Cost: 0.0059
# Epoch 084/100 | Batch 100/600 | Cost: 0.0085
# Epoch 084/100 | Batch 150/600 | Cost: 0.0012
# Epoch 084/100 | Batch 200/600 | Cost: 0.0038
# Epoch 084/100 | Batch 250/600 | Cost: 0.0018
# Epoch 084/100 | Batch 300/600 | Cost: 0.0045
# Epoch 084/100 | Batch 350/600 | Cost: 0.0056
# Epoch 084/100 | Batch 400/600 | Cost: 0.0038
# Epoch 084/100 | Batch 450/600 | Cost: 0.0061
# Epoch 084/100 | Batch 500/600 | Cost: 0.0048
# Epoch 084/100 | Batch 550/600 | Cost: 0.0020
# Epoch 084/100 | Cost: 0.0048
# Time: 22.24 min
# Epoch 085/100 | Batch 000/600 | Cost: 0.0087
# Epoch 085/100 | Batch 050/600 | Cost: 0.0022
# Epoch 085/100 | Batch 100/600 | Cost: 0.0053
# Epoch 085/100 | Batch 150/600 | Cost: 0.0047
# Epoch 085/100 | Batch 200/600 | Cost: 0.0025
# Epoch 085/100 | Batch 250/600 | Cost: 0.0025
# Epoch 085/100 | Batch 300/600 | Cost: 0.0078
# Epoch 085/100 | Batch 350/600 | Cost: 0.0010
# Epoch 085/100 | Batch 400/600 | Cost: 0.0063
# Epoch 085/100 | Batch 450/600 | Cost: 0.0032
# Epoch 085/100 | Batch 500/600 | Cost: 0.0036
# Epoch 085/100 | Batch 550/600 | Cost: 0.0033
# Epoch 085/100 | Cost: 0.0048
# Time: 22.50 min
# Epoch 086/100 | Batch 000/600 | Cost: 0.0035
# Epoch 086/100 | Batch 050/600 | Cost: 0.0014
# Epoch 086/100 | Batch 100/600 | Cost: 0.0020
# Epoch 086/100 | Batch 150/600 | Cost: 0.0025
# Epoch 086/100 | Batch 200/600 | Cost: 0.0022
# Epoch 086/100 | Batch 250/600 | Cost: 0.0045
# Epoch 086/100 | Batch 300/600 | Cost: 0.0032
# Epoch 086/100 | Batch 350/600 | Cost: 0.0029
# Epoch 086/100 | Batch 400/600 | Cost: 0.0037
# Epoch 086/100 | Batch 450/600 | Cost: 0.0044
# Epoch 086/100 | Batch 500/600 | Cost: 0.0049
# Epoch 086/100 | Batch 550/600 | Cost: 0.0048
# Epoch 086/100 | Cost: 0.0047
# Time: 22.76 min
# Epoch 087/100 | Batch 000/600 | Cost: 0.0033
# Epoch 087/100 | Batch 050/600 | Cost: 0.0029
# Epoch 087/100 | Batch 100/600 | Cost: 0.0025
# Epoch 087/100 | Batch 150/600 | Cost: 0.0050
# Epoch 087/100 | Batch 200/600 | Cost: 0.0056
# Epoch 087/100 | Batch 250/600 | Cost: 0.0079
# Epoch 087/100 | Batch 300/600 | Cost: 0.0014
# Epoch 087/100 | Batch 350/600 | Cost: 0.0008
# Epoch 087/100 | Batch 400/600 | Cost: 0.0054
# Epoch 087/100 | Batch 450/600 | Cost: 0.0069
# Epoch 087/100 | Batch 500/600 | Cost: 0.0039
# Epoch 087/100 | Batch 550/600 | Cost: 0.0063
# Epoch 087/100 | Cost: 0.0045
# Time: 23.03 min
# Epoch 088/100 | Batch 000/600 | Cost: 0.0041
# Epoch 088/100 | Batch 050/600 | Cost: 0.0074
# Epoch 088/100 | Batch 100/600 | Cost: 0.0083
# Epoch 088/100 | Batch 150/600 | Cost: 0.0083
# Epoch 088/100 | Batch 200/600 | Cost: 0.0035
# Epoch 088/100 | Batch 250/600 | Cost: 0.0023
# Epoch 088/100 | Batch 300/600 | Cost: 0.0027
# Epoch 088/100 | Batch 350/600 | Cost: 0.0023
# Epoch 088/100 | Batch 400/600 | Cost: 0.0047
# Epoch 088/100 | Batch 450/600 | Cost: 0.0021
# Epoch 088/100 | Batch 500/600 | Cost: 0.0032
# Epoch 088/100 | Batch 550/600 | Cost: 0.0050
# Epoch 088/100 | Cost: 0.0045
# Time: 23.29 min
# Epoch 089/100 | Batch 000/600 | Cost: 0.0035
# Epoch 089/100 | Batch 050/600 | Cost: 0.0008
# Epoch 089/100 | Batch 100/600 | Cost: 0.0051
# Epoch 089/100 | Batch 150/600 | Cost: 0.0057
# Epoch 089/100 | Batch 200/600 | Cost: 0.0046
# Epoch 089/100 | Batch 250/600 | Cost: 0.0065
# Epoch 089/100 | Batch 300/600 | Cost: 0.0050
# Epoch 089/100 | Batch 350/600 | Cost: 0.0031
# Epoch 089/100 | Batch 400/600 | Cost: 0.0050
# Epoch 089/100 | Batch 450/600 | Cost: 0.0039
# Epoch 089/100 | Batch 500/600 | Cost: 0.0036
# Epoch 089/100 | Batch 550/600 | Cost: 0.0027
# Epoch 089/100 | Cost: 0.0045
# Time: 23.55 min
# Epoch 090/100 | Batch 000/600 | Cost: 0.0091
# Epoch 090/100 | Batch 050/600 | Cost: 0.0041
# Epoch 090/100 | Batch 100/600 | Cost: 0.0043
# Epoch 090/100 | Batch 150/600 | Cost: 0.0010
# Epoch 090/100 | Batch 200/600 | Cost: 0.0022
# Epoch 090/100 | Batch 250/600 | Cost: 0.0028
# Epoch 090/100 | Batch 300/600 | Cost: 0.0040
# Epoch 090/100 | Batch 350/600 | Cost: 0.0048
# Epoch 090/100 | Batch 400/600 | Cost: 0.0014
# Epoch 090/100 | Batch 450/600 | Cost: 0.0055
# Epoch 090/100 | Batch 500/600 | Cost: 0.0022
# Epoch 090/100 | Batch 550/600 | Cost: 0.0031
# Epoch 090/100 | Cost: 0.0043
# Time: 23.82 min
# Epoch 091/100 | Batch 000/600 | Cost: 0.0030
# Epoch 091/100 | Batch 050/600 | Cost: 0.0020
# Epoch 091/100 | Batch 100/600 | Cost: 0.0071
# Epoch 091/100 | Batch 150/600 | Cost: 0.0068
# Epoch 091/100 | Batch 200/600 | Cost: 0.0037
# Epoch 091/100 | Batch 250/600 | Cost: 0.0025
# Epoch 091/100 | Batch 300/600 | Cost: 0.0043
# Epoch 091/100 | Batch 350/600 | Cost: 0.0062
# Epoch 091/100 | Batch 400/600 | Cost: 0.0010
# Epoch 091/100 | Batch 450/600 | Cost: 0.0048
# Epoch 091/100 | Batch 500/600 | Cost: 0.0042
# Epoch 091/100 | Batch 550/600 | Cost: 0.0036
# Epoch 091/100 | Cost: 0.0043
# Time: 24.10 min
# Epoch 092/100 | Batch 000/600 | Cost: 0.0035
# Epoch 092/100 | Batch 050/600 | Cost: 0.0044
# Epoch 092/100 | Batch 100/600 | Cost: 0.0013
# Epoch 092/100 | Batch 150/600 | Cost: 0.0052
# Epoch 092/100 | Batch 200/600 | Cost: 0.0037
# Epoch 092/100 | Batch 250/600 | Cost: 0.0030
# Epoch 092/100 | Batch 300/600 | Cost: 0.0062
# Epoch 092/100 | Batch 350/600 | Cost: 0.0025
# Epoch 092/100 | Batch 400/600 | Cost: 0.0055
# Epoch 092/100 | Batch 450/600 | Cost: 0.0044
# Epoch 092/100 | Batch 500/600 | Cost: 0.0022
# Epoch 092/100 | Batch 550/600 | Cost: 0.0044
# Epoch 092/100 | Cost: 0.0043
# Time: 24.36 min
# Epoch 093/100 | Batch 000/600 | Cost: 0.0026
# Epoch 093/100 | Batch 050/600 | Cost: 0.0052
# Epoch 093/100 | Batch 100/600 | Cost: 0.0029
# Epoch 093/100 | Batch 150/600 | Cost: 0.0025
# Epoch 093/100 | Batch 200/600 | Cost: 0.0021
# Epoch 093/100 | Batch 250/600 | Cost: 0.0027
# Epoch 093/100 | Batch 300/600 | Cost: 0.0062
# Epoch 093/100 | Batch 350/600 | Cost: 0.0044
# Epoch 093/100 | Batch 400/600 | Cost: 0.0039
# Epoch 093/100 | Batch 450/600 | Cost: 0.0037
# Epoch 093/100 | Batch 500/600 | Cost: 0.0050
# Epoch 093/100 | Batch 550/600 | Cost: 0.0015
# Epoch 093/100 | Cost: 0.0041
# Time: 24.63 min
# Epoch 094/100 | Batch 000/600 | Cost: 0.0029
# Epoch 094/100 | Batch 050/600 | Cost: 0.0038
# Epoch 094/100 | Batch 100/600 | Cost: 0.0049
# Epoch 094/100 | Batch 150/600 | Cost: 0.0018
# Epoch 094/100 | Batch 200/600 | Cost: 0.0019
# Epoch 094/100 | Batch 250/600 | Cost: 0.0052
# Epoch 094/100 | Batch 300/600 | Cost: 0.0021
# Epoch 094/100 | Batch 350/600 | Cost: 0.0025
# Epoch 094/100 | Batch 400/600 | Cost: 0.0036
# Epoch 094/100 | Batch 450/600 | Cost: 0.0053
# Epoch 094/100 | Batch 500/600 | Cost: 0.0036
# Epoch 094/100 | Batch 550/600 | Cost: 0.0076
# Epoch 094/100 | Cost: 0.0041
# Time: 24.90 min
# Epoch 095/100 | Batch 000/600 | Cost: 0.0036
# Epoch 095/100 | Batch 050/600 | Cost: 0.0020
# Epoch 095/100 | Batch 100/600 | Cost: 0.0016
# Epoch 095/100 | Batch 150/600 | Cost: 0.0024
# Epoch 095/100 | Batch 200/600 | Cost: 0.0047
# Epoch 095/100 | Batch 250/600 | Cost: 0.0067
# Epoch 095/100 | Batch 300/600 | Cost: 0.0051
# Epoch 095/100 | Batch 350/600 | Cost: 0.0038
# Epoch 095/100 | Batch 400/600 | Cost: 0.0049
# Epoch 095/100 | Batch 450/600 | Cost: 0.0030
# Epoch 095/100 | Batch 500/600 | Cost: 0.0031
# Epoch 095/100 | Batch 550/600 | Cost: 0.0019
# Epoch 095/100 | Cost: 0.0039
# Time: 25.17 min
# Epoch 096/100 | Batch 000/600 | Cost: 0.0055
# Epoch 096/100 | Batch 050/600 | Cost: 0.0032
# Epoch 096/100 | Batch 100/600 | Cost: 0.0043
# Epoch 096/100 | Batch 150/600 | Cost: 0.0015
# Epoch 096/100 | Batch 200/600 | Cost: 0.0754
# Epoch 096/100 | Batch 250/600 | Cost: 0.0041
# Epoch 096/100 | Batch 300/600 | Cost: 0.0017
# Epoch 096/100 | Batch 350/600 | Cost: 0.0108
# Epoch 096/100 | Batch 400/600 | Cost: 0.0030
# Epoch 096/100 | Batch 450/600 | Cost: 0.0033
# Epoch 096/100 | Batch 500/600 | Cost: 0.0065
# Epoch 096/100 | Batch 550/600 | Cost: 0.0085
# Epoch 096/100 | Cost: 0.0038
# Time: 25.43 min
# Epoch 097/100 | Batch 000/600 | Cost: 0.0032
# Epoch 097/100 | Batch 050/600 | Cost: 0.0050
# Epoch 097/100 | Batch 100/600 | Cost: 0.0032
# Epoch 097/100 | Batch 150/600 | Cost: 0.0040
# Epoch 097/100 | Batch 200/600 | Cost: 0.0023
# Epoch 097/100 | Batch 250/600 | Cost: 0.0015
# Epoch 097/100 | Batch 300/600 | Cost: 0.0054
# Epoch 097/100 | Batch 350/600 | Cost: 0.0030
# Epoch 097/100 | Batch 400/600 | Cost: 0.0022
# Epoch 097/100 | Batch 450/600 | Cost: 0.0118
# Epoch 097/100 | Batch 500/600 | Cost: 0.0033
# Epoch 097/100 | Batch 550/600 | Cost: 0.0006
# Epoch 097/100 | Cost: 0.0038
# Time: 25.70 min
# Epoch 098/100 | Batch 000/600 | Cost: 0.0041
# Epoch 098/100 | Batch 050/600 | Cost: 0.0012
# Epoch 098/100 | Batch 100/600 | Cost: 0.0021
# Epoch 098/100 | Batch 150/600 | Cost: 0.0017
# Epoch 098/100 | Batch 200/600 | Cost: 0.0080
# Epoch 098/100 | Batch 250/600 | Cost: 0.0021
# Epoch 098/100 | Batch 300/600 | Cost: 0.0025
# Epoch 098/100 | Batch 350/600 | Cost: 0.0048
# Epoch 098/100 | Batch 400/600 | Cost: 0.0049
# Epoch 098/100 | Batch 450/600 | Cost: 0.0040
# Epoch 098/100 | Batch 500/600 | Cost: 0.0024
# Epoch 098/100 | Batch 550/600 | Cost: 0.0078
# Epoch 098/100 | Cost: 0.0037
# Time: 25.96 min
# Epoch 099/100 | Batch 000/600 | Cost: 0.0022
# Epoch 099/100 | Batch 050/600 | Cost: 0.0022
# Epoch 099/100 | Batch 100/600 | Cost: 0.0028
# Epoch 099/100 | Batch 150/600 | Cost: 0.0021
# Epoch 099/100 | Batch 200/600 | Cost: 0.0026
# Epoch 099/100 | Batch 250/600 | Cost: 0.0051
# Epoch 099/100 | Batch 300/600 | Cost: 0.0036
# Epoch 099/100 | Batch 350/600 | Cost: 0.0022
# Epoch 099/100 | Batch 400/600 | Cost: 0.0037
# Epoch 099/100 | Batch 450/600 | Cost: 0.0040
# Epoch 099/100 | Batch 500/600 | Cost: 0.0035
# Epoch 099/100 | Batch 550/600 | Cost: 0.0035
# Epoch 099/100 | Cost: 0.0037
# Time: 26.23 min
# Epoch 100/100 | Batch 000/600 | Cost: 0.0031
# Epoch 100/100 | Batch 050/600 | Cost: 0.0026
# Epoch 100/100 | Batch 100/600 | Cost: 0.0012
# Epoch 100/100 | Batch 150/600 | Cost: 0.0018
# Epoch 100/100 | Batch 200/600 | Cost: 0.0017
# Epoch 100/100 | Batch 250/600 | Cost: 0.0018
# Epoch 100/100 | Batch 300/600 | Cost: 0.0019
# Epoch 100/100 | Batch 350/600 | Cost: 0.0402
# Epoch 100/100 | Batch 400/600 | Cost: 0.0050
# Epoch 100/100 | Batch 450/600 | Cost: 0.0034
# Epoch 100/100 | Batch 500/600 | Cost: 0.0018
# Epoch 100/100 | Batch 550/600 | Cost: 0.0031
# Epoch 100/100 | Cost: 0.0037
# Time: 26.49 min
# Total Time: 26.49 min

# %% [markdown]
# ##Evaluation

# %%
plt.plot(range(len(miniBatchCost)),miniBatchCost)
plt.ylabel("Mean Squared Error")
plt.xlabel("MiniBatch")
plt.show()

plt.plot(range(len(epochCost)),epochCost)
plt.ylabel("Mean Squared Error")
plt.xlabel("Epoch")
plt.show()

# %%
def computeAcc(net,dataLoader):
  correctPred,numExamples = 0 , 0
  with torch.no_grad():
    for features,targets in dataLoader:
        features = features.view(-1, 28*28).to(DEVICE)
        targets = targets.to(DEVICE)
        logits = net.forward(features)
        pred = torch.argmax(logits, 1)
#         num_examples += targets.size(0)
        numExamples+=targets.size(0)
        correctPred+=(pred==targets).sum()
      # yOneHot = toOneHot(targets,model.numClasses)
      # loss = torch.sum((yOneHot - probas)**2, dim=0)
      # numExamples+=targets.size(0)
      # currMSE+=loss
    # currMSE = torch.mean(currMSE/numExamples, dim=0)
    return correctPred.float()/numExamples * 100

# %%
print("Training Accuracy :%.2f" % (computeAcc(model,trainLoader)))
print("Testing  Accuracy :%.2f" % (computeAcc(model,testLoader )))
# Out:
# Training Accuracy :99.99
# Testing  Accuracy :97.88
